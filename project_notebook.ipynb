# %%
# Partially adopted from https://github.com/gordicaleksa/pytorch-GAT

# @misc{Gordić2020PyTorchGAT,
#   author = {Gordić, Aleksa},
#   title = {pytorch-GAT},
#   year = {2020},
#   publisher = {GitHub},
#   journal = {GitHub repository},
#   howpublished = {\url{https://github.com/gordicaleksa/pytorch-GAT}},
# }

# import base files and mount google drive 
import torch
from google.colab import drive
drive.mount('/content/drive')
import json
import os
import enum
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install torch_geometric
# !pip install igraph
# !apt-get install libcairo2-dev libjpeg-dev libgif-dev
# !pip install pycairo
# !pip install cairocffi
# !pip install GitPython
# !pip install ray[tune]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch_geometric
#   Downloading torch_geometric-2.3.1.tar.gz (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.6/661.6 kB 28.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.27.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.65.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (1.26.15)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (1.2.0)
# Building wheels for collected packages: torch_geometric
#   Building wheel for torch_geometric (pyproject.toml) ... done
#   Created wheel for torch_geometric: filename=torch_geometric-2.3.1-py3-none-any.whl size=910476 sha256=3c6d739a26af6f1705b054ad597f24685320a7e289012b30c922256cc0a5ab1f
#   Stored in directory: /root/.cache/pip/wheels/ac/dc/30/e2874821ff308ee67dcd7a66dbde912411e19e35a1addda028
# Successfully built torch_geometric
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.3.1

# %%
# Run SRGNN
import torch_geometric

# %%
# Visualization related imports
import matplotlib.pyplot as plt
import networkx as nx
from networkx.readwrite import json_graph
import igraph as ig

# Main computation libraries
import numpy as np

# Deep learning related imports
import torch
from torch.utils.data import DataLoader, Dataset

# Analysis and Metrics
from sklearn.metrics import f1_score
from ray.air import session
import ray
from ray.tune.schedulers import ASHAScheduler
from ray import tune
from ray.tune.stopper import (CombinedStopper, 
MaximumIterationStopper, TrialPlateauStopper, ExperimentPlateauStopper)
from ray import air

# %% [markdown]
# ## Data Preprocessing - PPI

# %%
DATA_DIR_PATH = os.path.join('/content/drive/MyDrive/DL4H_final/GAT-pt', 'data')
PPI_PATH = os.path.join(DATA_DIR_PATH, 'ppi')
PPI_URL = 'https://data.dgl.ai/dataset/ppi.zip'  # preprocessed PPI data from Deep Graph Library

# %% [markdown]
# ## Recreation of GAT model

# %%
# %cd /content/drive/MyDrive/DL4H_Final/

# %%
# Let's just define dummy visualization functions for now - just to stop Python interpreter from complaining!
# We'll define them in a moment, properly, I swear.
from torch.hub import download_url_to_file
import zipfile
from src.datasets_dat import *

def plot_in_out_degree_distributions():
    pass

def visualize_graph():
    pass

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # checking whether you have a GPU

config = {
    'dataset_name': DatasetType.PPI.name,
    'should_visualize': False,
    'batch_size': 1,
    'ppi_load_test_only': False  # small optimization for loading test graphs only, we won't use it here
}

data_loader_train, data_loader_val, data_loader_test = load_graph_data(config, device)
# Let's fetch a single batch from the train graph data loader
node_features, node_labels, edge_index = next(iter(data_loader_train))

print('*' * 20)
print(node_features.shape, node_features.dtype)
print(node_labels.shape, node_labels.dtype)
print(edge_index.shape, edge_index.dtype)

# %%
#@title
from src.GAT_model import *
from ray import air
scheduler = ASHAScheduler(
    time_attr="training_iteration",
    metric="micro_f1",
    mode="max",
    grace_period=1,
)
# tune_config=tune.TuneConfig(scheduler=scheduler),

stopper = CombinedStopper(
    MaximumIterationStopper(max_iter=10),
    TrialPlateauStopper(metric="micro_f1"),
)

tuner = tune.Tuner(
    tune.with_resources(train_gat_ppi, {"gpu": 1,'cpu': 12}),
    run_config=air.RunConfig(
      name="gnn_exp_heads_per_layer",
      stop=stopper,
      verbose=1,
  ),
    tune_config=tune.TuneConfig(scheduler=scheduler, num_samples=1),
    param_space={
        # distribution for resampling
        # GNNs, contrary to CNNs, are often shallow (it ultimately depends on the graph properties)
        'num_of_epochs': 200,
         'patience_period': 50,
         'lr': 0.005,
         'weight_decay': 0,
         'should_test': True,
         'force_cpu': False,
         'dataset_name': 'PPI',
         'batch_size': 2,
         'should_visualize': False,
         'enable_tensorboard': False,
         'console_log_freq': 10,
         'checkpoint_freq': 5,
         'ppi_load_test_only': False,
        "num_of_layers": 3 , # PPI has got 42% of nodes with all 0 features - that's why 3 layers are useful
        'num_heads_per_layer1': tune.grid_search(list(range(3, 6))),
        "num_heads_per_layer2": tune.grid_search(list(range(3, 6))),  # other values may give even better results from the reported ones
        'num_heads_per_layer3': tune.grid_search(list(range(3, 6))),
        "num_features_per_layer": [PPI_NUM_INPUT_FEATURES, 64, 64, PPI_NUM_CLASSES],  # 64 would also give ~0.975 uF1!
        "add_skip_connection": True,  # skip connection is very important! (keep it otherwise micro-F1 is almost 0)
        "bias": True,  # bias doesn't matter that much
        "dropout": 0.,  # dropout hurts the performance (best to keep it at 0)
        #         "lr": lambda: np.random.uniform(0.0001, 1),
        #         # allow perturbations within this set of categorical values
        #         "momentum": [0.8, 0.9, 0.99],
    }
)
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-05-08 06:10:45</td></tr>
# <tr><td>Running for: </td><td>02:23:51.33        </td></tr>
# <tr><td>Memory:      </td><td>5.4/83.5 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=14<br>Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: 0.9776308807383904<br>Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/49.67 GiB heap, 0.0/24.84 GiB objects (0.0/1.0 accelerator_type:A100)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name               </th><th>status    </th><th>loc               </th><th style="text-align: right;">  num_heads_per_layer1</th><th style="text-align: right;">  num_heads_per_layer2</th><th style="text-align: right;">  num_heads_per_layer3</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  micro_f1</th></tr>
# </thead>
# <tbody>
# <tr><td>train_gat_ppi_f9577_00000</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         328.027</td><td style="text-align: right;">  0.956045</td></tr>
# <tr><td>train_gat_ppi_f9577_00001</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         327.455</td><td style="text-align: right;">  0.972534</td></tr>
# <tr><td>train_gat_ppi_f9577_00002</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         331.971</td><td style="text-align: right;">  0.974586</td></tr>
# <tr><td>train_gat_ppi_f9577_00003</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         327.032</td><td style="text-align: right;">  0.862875</td></tr>
# <tr><td>train_gat_ppi_f9577_00004</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         305.342</td><td style="text-align: right;">  0.927491</td></tr>
# <tr><td>train_gat_ppi_f9577_00005</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         329.335</td><td style="text-align: right;">  0.906079</td></tr>
# <tr><td>train_gat_ppi_f9577_00006</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         330.507</td><td style="text-align: right;">  0.977865</td></tr>
# <tr><td>train_gat_ppi_f9577_00007</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         329.201</td><td style="text-align: right;">  0.978031</td></tr>
# <tr><td>train_gat_ppi_f9577_00008</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         177.317</td><td style="text-align: right;">  0.942868</td></tr>
# <tr><td>train_gat_ppi_f9577_00009</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         247.575</td><td style="text-align: right;">  0.869984</td></tr>
# <tr><td>train_gat_ppi_f9577_00010</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         325.861</td><td style="text-align: right;">  0.872136</td></tr>
# <tr><td>train_gat_ppi_f9577_00011</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         325.529</td><td style="text-align: right;">  0.971165</td></tr>
# <tr><td>train_gat_ppi_f9577_00012</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         326.831</td><td style="text-align: right;">  0.970779</td></tr>
# <tr><td>train_gat_ppi_f9577_00013</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         325.944</td><td style="text-align: right;">  0.975721</td></tr>
# <tr><td>train_gat_ppi_f9577_00014</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         329.929</td><td style="text-align: right;">  0.982132</td></tr>
# <tr><td>train_gat_ppi_f9577_00015</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         328.077</td><td style="text-align: right;">  0.976604</td></tr>
# <tr><td>train_gat_ppi_f9577_00016</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     5</td><td style="text-align: right;">
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [3, 3, 3], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.41 [s] | epoch=1 | batch=1 | train micro-F1=0.3649627973361994.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.71 [s] | epoch=1 | batch=1 | val micro-F1=0.41822505322945075
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.37 [s] | epoch=11 | batch=1 | train micro-F1=0.7194236952845541.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.78 [s] | epoch=11 | batch=1 | val micro-F1=0.6883074626294332
# (train_gat_ppi pid=106316) GAT training: time elapsed= 30.99 [s] | epoch=21 | batch=1 | train micro-F1=0.8143812835915271.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.38 [s] | epoch=21 | batch=1 | val micro-F1=0.8104263494804271
# (train_gat_ppi pid=106316) GAT training: time elapsed= 46.62 [s] | epoch=31 | batch=1 | train micro-F1=0.8430481234479014.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 48.05 [s] | epoch=31 | batch=1 | val micro-F1=0.8206348036423818
# (train_gat_ppi pid=106316) GAT training: time elapsed= 62.40 [s] | epoch=41 | batch=1 | train micro-F1=0.8841213532510661.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 63.80 [s] | epoch=41 | batch=1 | val micro-F1=0.859802496007993
# (train_gat_ppi pid=106316) GAT training: time elapsed= 77.93 [s] | epoch=51 | batch=1 | train micro-F1=0.880086382445232.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 79.42 [s] | epoch=51 | batch=1 | val micro-F1=0.8792832393970684
# (train_gat_ppi pid=106316) GAT training: time elapsed= 93.73 [s] | epoch=61 | batch=1 | train micro-F1=0.9400462247973671.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 95.13 [s] | epoch=61 | batch=1 | val micro-F1=0.887658199443497
# (train_gat_ppi pid=106316) GAT training: time elapsed= 109.41 [s] | epoch=71 | batch=1 | train micro-F1=0.9333110555855124.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 110.89 [s] | epoch=71 | batch=1 | val micro-F1=0.9043409749958966
# (train_gat_ppi pid=106316) GAT training: time elapsed= 125.35 [s] | epoch=81 | batch=1 | train micro-F1=0.9250150422953953.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 126.73 [s] | epoch=81 | batch=1 | val micro-F1=0.9087738321906405
# (train_gat_ppi pid=106316) GAT training: time elapsed= 141.01 [s] | epoch=91 | batch=1 | train micro-F1=0.9513948192428124.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 142.46 [s] | epoch=91 | batch=1 | val micro-F1=0.917924142669531
# (train_gat_ppi pid=106316) GAT training: time elapsed= 156.75 [s] | epoch=101 | batch=1 | train micro-F1=0.9247989065688982.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 158.18 [s] | epoch=101 | batch=1 | val micro-F1=0.9198579452520488
# (train_gat_ppi pid=106316) GAT training: time elapsed= 172.50 [s] | epoch=111 | batch=1 | train micro-F1=0.9612070943465493.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 173.93 [s] | epoch=111 | batch=1 | val micro-F1=0.9263510584298595
# (train_gat_ppi pid=106316) GAT training: time elapsed= 188.23 [s] | epoch=121 | batch=1 | train micro-F1=0.9313530571324631.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 189.59 [s] | epoch=121 | batch=1 | val micro-F1=0.9280317657710725
# (train_gat_ppi pid=106316) GAT training: time elapsed= 203.84 [s] | epoch=131 | batch=1 | train micro-F1=0.952612819043982.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 205.22 [s] | epoch=131 | batch=1 | val micro-F1=0.9318120360435802
# (train_gat_ppi pid=106316) GAT training: time elapsed= 219.49 [s] | epoch=141 | batch=1 | train micro-F1=0.9482763281082981.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 220.88 [s] | epoch=141 | batch=1 | val micro-F1=0.931473248505289
# (train_gat_ppi pid=106316) GAT training: time elapsed= 235.07 [s] | epoch=151 | batch=1 | train micro-F1=0.9675882708253254.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 236.50 [s] | epoch=151 | batch=1 | val micro-F1=0.9362428941466892
# (train_gat_ppi pid=106316) GAT training: time elapsed= 250.81 [s] | epoch=161 | batch=1 | train micro-F1=0.9465684444089504.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 252.17 [s] | epoch=161 | batch=1 | val micro-F1=0.9320500078464193
# (train_gat_ppi pid=106316) GAT training: time elapsed= 267.10 [s] | epoch=171 | batch=1 | train micro-F1=0.9625225339194788.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 268.48 [s] | epoch=171 | batch=1 | val micro-F1=0.9388121275902894
# (train_gat_ppi pid=106316) GAT training: time elapsed= 282.74 [s] | epoch=181 | batch=1 | train micro-F1=0.9683864133252191.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 284.23 [s] | epoch=181 | batch=1 | val micro-F1=0.9350288405333568
# (train_gat_ppi pid=106316) GAT training: time elapsed= 298.54 [s] | epoch=191 | batch=1 | train micro-F1=0.9752931914346386.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 299.97 [s] | epoch=191 | batch=1 | val micro-F1=0.9405385771707523
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9560450654175416
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [4, 3, 3], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.13 [s] | epoch=1 | batch=1 | train micro-F1=0.3725199248190658.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.48 [s] | epoch=1 | batch=1 | val micro-F1=0.5040021737125365
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.27 [s] | epoch=11 | batch=1 | train micro-F1=0.7698885597597434.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.70 [s] | epoch=11 | batch=1 | val micro-F1=0.726961819969535
# (train_gat_ppi pid=106316) GAT training: time elapsed= 30.82 [s] | epoch=21 | batch=1 | train micro-F1=0.8828672887934594.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.25 [s] | epoch=21 | batch=1 | val micro-F1=0.8442474841398595
# (train_gat_ppi pid=106316) GAT training: time elapsed= 46.50 [s] | epoch=31 | batch=1 | train micro-F1=0.9326664445026303.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 47.94 [s] | epoch=31 | batch=1 | val micro-F1=0.8862578004868947
# (train_gat_ppi pid=106316) GAT training: time elapsed= 62.16 [s] | epoch=41 | batch=1 | train micro-F1=0.9165260676550478.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 63.66 [s] | epoch=41 | batch=1 | val micro-F1=0.9119106972490778
# (train_gat_ppi pid=106316) GAT training: time elapsed= 77.84 [s] | epoch=51 | batch=1 | train micro-F1=0.915362555593952.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 79.35 [s] | epoch=51 | batch=1 | val micro-F1=0.8937714552979695
# (train_gat_ppi pid=106316) GAT training: time elapsed= 93.62 [s] | epoch=61 | batch=1 | train micro-F1=0.9406055827748682.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 95.06 [s] | epoch=61 | batch=1 | val micro-F1=0.9107160439800885
# (train_gat_ppi pid=106316) GAT training: time elapsed= 109.30 [s] | epoch=71 | batch=1 | train micro-F1=0.9347853921034244.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 110.76 [s] | epoch=71 | batch=1 | val micro-F1=0.9217031480623813
# (train_gat_ppi pid=106316) GAT training: time elapsed= 125.01 [s] | epoch=81 | batch=1 | train micro-F1=0.9443267193219033.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 126.46 [s] | epoch=81 | batch=1 | val micro-F1=0.9304065496672311
# (train_gat_ppi pid=106316) GAT training: time elapsed= 140.77 [s] | epoch=91 | batch=1 | train micro-F1=0.9694697533273917.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 142.18 [s] | epoch=91 | batch=1 | val micro-F1=0.9323341706164268
# (train_gat_ppi pid=106316) GAT training: time elapsed= 156.41 [s] | epoch=101 | batch=1 | train micro-F1=0.9660026504993164.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 157.80 [s] | epoch=101 | batch=1 | val micro-F1=0.93649980067202
# (train_gat_ppi pid=106316) GAT training: time elapsed= 172.02 [s] | epoch=111 | batch=1 | train micro-F1=0.976347191472406.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 173.44 [s] | epoch=111 | batch=1 | val micro-F1=0.9411537437861135
# (train_gat_ppi pid=106316) GAT training: time elapsed= 187.66 [s] | epoch=121 | batch=1 | train micro-F1=0.9758100967038118.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 189.08 [s] | epoch=121 | batch=1 | val micro-F1=0.9447733340864605
# (train_gat_ppi pid=106316) GAT training: time elapsed= 203.27 [s] | epoch=131 | batch=1 | train micro-F1=0.9644019076239628.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 204.68 [s] | epoch=131 | batch=1 | val micro-F1=0.9482888287618536
# (train_gat_ppi pid=106316) GAT training: time elapsed= 219.04 [s] | epoch=141 | batch=1 | train micro-F1=0.9576983797257997.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 220.41 [s] | epoch=141 | batch=1 | val micro-F1=0.9301204068183032
# (train_gat_ppi pid=106316) GAT training: time elapsed= 234.79 [s] | epoch=151 | batch=1 | train micro-F1=0.9857712892022097.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 236.23 [s] | epoch=151 | batch=1 | val micro-F1=0.9526533948274855
# (train_gat_ppi pid=106316) GAT training: time elapsed= 250.61 [s] | epoch=161 | batch=1 | train micro-F1=0.9818177752767955.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 252.11 [s] | epoch=161 | batch=1 | val micro-F1=0.9545148014939827
# (train_gat_ppi pid=106316) GAT training: time elapsed= 266.51 [s] | epoch=171 | batch=1 | train micro-F1=0.9626659876365962.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 267.93 [s] | epoch=171 | batch=1 | val micro-F1=0.9561185511950236
# (train_gat_ppi pid=106316) GAT training: time elapsed= 282.28 [s] | epoch=181 | batch=1 | train micro-F1=0.9838686397283718.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 283.74 [s] | epoch=181 | batch=1 | val micro-F1=0.9551148001356904
# (train_gat_ppi pid=106316) GAT training: time elapsed= 298.09 [s] | epoch=191 | batch=1 | train micro-F1=0.9707378276648275.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 299.55 [s] | epoch=191 | batch=1 | val micro-F1=0.9493413877736568
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9725342033309101
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [5, 3, 3], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.17 [s] | epoch=1 | batch=1 | train micro-F1=0.3814715169377974.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.48 [s] | epoch=1 | batch=1 | val micro-F1=0.460934007502492
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.32 [s] | epoch=11 | batch=1 | train micro-F1=0.728990415035973.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.71 [s] | epoch=11 | batch=1 | val micro-F1=0.7352154641941722
# (train_gat_ppi pid=106316) GAT training: time elapsed= 30.93 [s] | epoch=21 | batch=1 | train micro-F1=0.866687730063685.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.40 [s] | epoch=21 | batch=1 | val micro-F1=0.8049621073817136
# (train_gat_ppi pid=106316) GAT training: time elapsed= 46.72 [s] | epoch=31 | batch=1 | train micro-F1=0.9344824269950146.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 48.16 [s] | epoch=31 | batch=1 | val micro-F1=0.8908716056032103
# (train_gat_ppi pid=106316) GAT training: time elapsed= 62.52 [s] | epoch=41 | batch=1 | train micro-F1=0.9487446648855071.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 63.91 [s] | epoch=41 | batch=1 | val micro-F1=0.9049119189171402
# (train_gat_ppi pid=106316) GAT training: time elapsed= 78.23 [s] | epoch=51 | batch=1 | train micro-F1=0.959957273516256.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 79.72 [s] | epoch=51 | batch=1 | val micro-F1=0.9316832500184581
# (train_gat_ppi pid=106316) GAT training: time elapsed= 94.07 [s] | epoch=61 | batch=1 | train micro-F1=0.9744606798883855.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 95.52 [s] | epoch=61 | batch=1 | val micro-F1=0.9388233806605758
# (train_gat_ppi pid=106316) GAT training: time elapsed= 109.81 [s] | epoch=71 | batch=1 | train micro-F1=0.9706443063890421.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 111.29 [s] | epoch=71 | batch=1 | val micro-F1=0.946499954525178
# (train_gat_ppi pid=106316) GAT training: time elapsed= 125.59 [s] | epoch=81 | batch=1 | train micro-F1=0.9758806414091626.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 127.05 [s] | epoch=81 | batch=1 | val micro-F1=0.9450405715312803
# (train_gat_ppi pid=106316) GAT training: time elapsed= 141.34 [s] | epoch=91 | batch=1 | train micro-F1=0.9555606372436923.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 142.77 [s] | epoch=91 | batch=1 | val micro-F1=0.924385846782076
# (train_gat_ppi pid=106316) GAT training: time elapsed= 156.99 [s] | epoch=101 | batch=1 | train micro-F1=0.95156117369061.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 158.46 [s] | epoch=101 | batch=1 | val micro-F1=0.951690354599881
# (train_gat_ppi pid=106316) GAT training: time elapsed= 172.74 [s] | epoch=111 | batch=1 | train micro-F1=0.9708575956619094.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 174.14 [s] | epoch=111 | batch=1 | val micro-F1=0.9550817744288856
# (train_gat_ppi pid=106316) GAT training: time elapsed= 188.48 [s] | epoch=121 | batch=1 | train micro-F1=0.9848551266295877.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 189.89 [s] | epoch=121 | batch=1 | val micro-F1=0.9461759877188118
# (train_gat_ppi pid=106316) GAT training: time elapsed= 204.27 [s] | epoch=131 | batch=1 | train micro-F1=0.992442459635864.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 205.69 [s] | epoch=131 | batch=1 | val micro-F1=0.9624564689230184
# (train_gat_ppi pid=106316) GAT training: time elapsed= 220.98 [s] | epoch=141 | batch=1 | train micro-F1=0.9294861985446601.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 222.51 [s] | epoch=141 | batch=1 | val micro-F1=0.8535212224877943
# (train_gat_ppi pid=106316) GAT training: time elapsed= 237.13 [s] | epoch=151 | batch=1 | train micro-F1=0.9796432481663421.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 238.65 [s] | epoch=151 | batch=1 | val micro-F1=0.960416057207866
# (train_gat_ppi pid=106316) GAT training: time elapsed= 253.30 [s] | epoch=161 | batch=1 | train micro-F1=0.993965514800205.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 254.77 [s] | epoch=161 | batch=1 | val micro-F1=0.9650746801649568
# (train_gat_ppi pid=106316) GAT training: time elapsed= 269.39 [s] | epoch=171 | batch=1 | train micro-F1=0.9817920980748749.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 270.95 [s] | epoch=171 | batch=1 | val micro-F1=0.9646741824922938
# (train_gat_ppi pid=106316) GAT training: time elapsed= 285.64 [s] | epoch=181 | batch=1 | train micro-F1=0.9901926436005173.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 287.08 [s] | epoch=181 | batch=1 | val micro-F1=0.9615572338676531
# (train_gat_ppi pid=106316) GAT training: time elapsed= 301.84 [s] | epoch=191 | batch=1 | train micro-F1=0.9869732258215822.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 303.25 [s] | epoch=191 | batch=1 | val micro-F1=0.9661687417138465
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9745859002564634
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [3, 4, 3], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.16 [s] | epoch=1 | batch=1 | train micro-F1=0.3719373896205187.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.46 [s] | epoch=1 | batch=1 | val micro-F1=0.4516315771725324
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.19 [s] | epoch=11 | batch=1 | train micro-F1=0.6869615163699024.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.55 [s] | epoch=11 | batch=1 | val micro-F1=0.7230849545818397
# (train_gat_ppi pid=106316) GAT training: time elapsed= 30.65 [s] | epoch=21 | batch=1 | train micro-F1=0.8728109429704994.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.08 [s] | epoch=21 | batch=1 | val micro-F1=0.8347938880949765
# (train_gat_ppi pid=106316) GAT training: time elapsed= 46.31 [s] | epoch=31 | batch=1 | train micro-F1=0.9164143561830244.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 47.72 [s] | epoch=31 | batch=1 | val micro-F1=0.8685094555950624
# (train_gat_ppi pid=106316) GAT training: time elapsed= 61.99 [s] | epoch=41 | batch=1 | train micro-F1=0.9196848226765448.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 63.44 [s] | epoch=41 | batch=1 | val micro-F1=0.9085361417494692
# (train_gat_ppi pid=106316) GAT training: time elapsed= 77.71 [s] | epoch=51 | batch=1 | train micro-F1=0.8919238576246264.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 79.12 [s] | epoch=51 | batch=1 | val micro-F1=0.8846930334783283
# (train_gat_ppi pid=106316) GAT training: time elapsed= 93.35 [s] | epoch=61 | batch=1 | train micro-F1=0.9334285530550976.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 94.78 [s] | epoch=61 | batch=1 | val micro-F1=0.9033884127891452
# (train_gat_ppi pid=106316) GAT training: time elapsed= 108.88 [s] | epoch=71 | batch=1 | train micro-F1=0.9122910564940923.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 110.36 [s] | epoch=71 | batch=1 | val micro-F1=0.91911621019537
# (train_gat_ppi pid=106316) GAT training: time elapsed= 124.53 [s] | epoch=81 | batch=1 | train micro-F1=0.9314170177752602.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 125.98 [s] | epoch=81 | batch=1 | val micro-F1=0.9259050401816722
# (train_gat_ppi pid=106316) GAT training: time elapsed= 140.14 [s] | epoch=91 | batch=1 | train micro-F1=0.9615661332553639.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 141.60 [s] | epoch=91 | batch=1 | val micro-F1=0.9311043829671114
# (train_gat_ppi pid=106316) GAT training: time elapsed= 155.89 [s] | epoch=101 | batch=1 | train micro-F1=0.949729300153976.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 157.30 [s] | epoch=101 | batch=1 | val micro-F1=0.9323176001438931
# (train_gat_ppi pid=106316) GAT training: time elapsed= 171.60 [s] | epoch=111 | batch=1 | train micro-F1=0.9700527542224985.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 173.05 [s] | epoch=111 | batch=1 | val micro-F1=0.9357119259993393
# (train_gat_ppi pid=106316) GAT training: time elapsed= 187.59 [s] | epoch=121 | batch=1 | train micro-F1=0.9843378611169001.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 189.02 [s] | epoch=121 | batch=1 | val micro-F1=0.9405684754521965
# (train_gat_ppi pid=106316) GAT training: time elapsed= 203.33 [s] | epoch=131 | batch=1 | train micro-F1=0.9634826735848787.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 204.77 [s] | epoch=131 | batch=1 | val micro-F1=0.9426819456826632
# (train_gat_ppi pid=106316) GAT training: time elapsed= 219.07 [s] | epoch=141 | batch=1 | train micro-F1=0.9795901820823939.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 220.49 [s] | epoch=141 | batch=1 | val micro-F1=0.9481772131681808
# (train_gat_ppi pid=106316) GAT training: time elapsed= 234.86 [s] | epoch=151 | batch=1 | train micro-F1=0.9681896210220521.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 236.24 [s] | epoch=151 | batch=1 | val micro-F1=0.9468903577134608
# (train_gat_ppi pid=106316) GAT training: time elapsed= 250.52 [s] | epoch=161 | batch=1 | train micro-F1=0.9854369627712478.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 251.94 [s] | epoch=161 | batch=1 | val micro-F1=0.9475739580495779
# (train_gat_ppi pid=106316) GAT training: time elapsed= 266.30 [s] | epoch=171 | batch=1 | train micro-F1=0.986049930636541.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 267.72 [s] | epoch=171 | batch=1 | val micro-F1=0.9520321243411155
# (train_gat_ppi pid=106316) GAT training: time elapsed= 282.07 [s] | epoch=181 | batch=1 | train micro-F1=0.9780817326583917.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 283.50 [s] | epoch=181 | batch=1 | val micro-F1=0.9527938092514602
# (train_gat_ppi pid=106316) GAT training: time elapsed= 297.77 [s] | epoch=191 | batch=1 | train micro-F1=0.8260188251154419.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 299.20 [s] | epoch=191 | batch=1 | val micro-F1=0.7917674509653916
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.8628751614224888
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [4, 4, 3], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.13 [s] | epoch=1 | batch=1 | train micro-F1=0.3916259642648948.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.47 [s] | epoch=1 | batch=1 | val micro-F1=0.4767347850600513
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.29 [s] | epoch=11 | batch=1 | train micro-F1=0.7297499254434024.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.70 [s] | epoch=11 | batch=1 | val micro-F1=0.7172829888287816
# (train_gat_ppi pid=106316) GAT training: time elapsed= 30.96 [s] | epoch=21 | batch=1 | train micro-F1=0.8772381576620161.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.37 [s] | epoch=21 | batch=1 | val micro-F1=0.8348935271097065
# (train_gat_ppi pid=106316) GAT training: time elapsed= 46.78 [s] | epoch=31 | batch=1 | train micro-F1=0.8966670484480586.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 48.21 [s] | epoch=31 | batch=1 | val micro-F1=0.8966634727335316
# (train_gat_ppi pid=106316) GAT training: time elapsed= 62.50 [s] | epoch=41 | batch=1 | train micro-F1=0.9666702657854509.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 63.94 [s] | epoch=41 | batch=1 | val micro-F1=0.9169394723410248
# (train_gat_ppi pid=106316) GAT training: time elapsed= 78.29 [s] | epoch=51 | batch=1 | train micro-F1=0.9548334942626817.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 79.66 [s] | epoch=51 | batch=1 | val micro-F1=0.9377548235029053
# (train_gat_ppi pid=106316) GAT training: time elapsed= 93.87 [s] | epoch=61 | batch=1 | train micro-F1=0.9735390393057424.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 95.26 [s] | epoch=61 | batch=1 | val micro-F1=0.9489561322499227
# (train_gat_ppi pid=106316) GAT training: time elapsed= 109.47 [s] | epoch=71 | batch=1 | train micro-F1=0.982324742655346.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 110.89 [s] | epoch=71 | batch=1 | val micro-F1=0.9542503677311098
# (train_gat_ppi pid=106316) GAT training: time elapsed= 125.19 [s] | epoch=81 | batch=1 | train micro-F1=0.9669551203292313.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 126.57 [s] | epoch=81 | batch=1 | val micro-F1=0.9522545781259906
# (train_gat_ppi pid=106316) GAT training: time elapsed= 140.91 [s] | epoch=91 | batch=1 | train micro-F1=0.9745781064648861.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 142.35 [s] | epoch=91 | batch=1 | val micro-F1=0.9588225373308598
# (train_gat_ppi pid=106316) GAT training: time elapsed= 157.41 [s] | epoch=101 | batch=1 | train micro-F1=0.9912013517255408.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 158.86 [s] | epoch=101 | batch=1 | val micro-F1=0.9587768522577816
# (train_gat_ppi pid=106316) GAT training: time elapsed= 173.40 [s] | epoch=111 | batch=1 | train micro-F1=0.9885822575447911.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 174.80 [s] | epoch=111 | batch=1 | val micro-F1=0.9664827621933846
# (train_gat_ppi pid=106316) GAT training: time elapsed= 189.26 [s] | epoch=121 | batch=1 | train micro-F1=0.975298619969848.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 190.75 [s] | epoch=121 | batch=1 | val micro-F1=0.9524585841719031
# (train_gat_ppi pid=106316) GAT training: time elapsed= 205.25 [s] | epoch=131 | batch=1 | train micro-F1=0.9946371622443528.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 206.70 [s] | epoch=131 | batch=1 | val micro-F1=0.9665979078285614
# (train_gat_ppi pid=106316) GAT training: time elapsed= 221.17 [s] | epoch=141 | batch=1 | train micro-F1=0.7403988648904304.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 222.67 [s] | epoch=141 | batch=1 | val micro-F1=0.703239267224778
# (train_gat_ppi pid=106316) GAT training: time elapsed= 237.06 [s] | epoch=151 | batch=1 | train micro-F1=0.866236405175772.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 238.56 [s] | epoch=151 | batch=1 | val micro-F1=0.8445056993714712
# (train_gat_ppi pid=106316) GAT training: time elapsed= 253.12 [s] | epoch=161 | batch=1 | train micro-F1=0.8833204103542884.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 254.52 [s] | epoch=161 | batch=1 | val micro-F1=0.873856158550747
# (train_gat_ppi pid=106316) GAT training: time elapsed= 269.00 [s] | epoch=171 | batch=1 | train micro-F1=0.9300594782502206.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 270.43 [s] | epoch=171 | batch=1 | val micro-F1=0.8898207874298975
# (train_gat_ppi pid=106316) GAT training: time elapsed= 284.85 [s] | epoch=181 | batch=1 | train micro-F1=0.9073595822549049.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 286.29 [s] | epoch=181 | batch=1 | val micro-F1=0.9006753360288493
# (train_gat_ppi pid=106316) Stopping the training, the universe has no more patience for this training.
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9274907028049165
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [5, 4, 3], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.16 [s] | epoch=1 | batch=1 | train micro-F1=0.3802298693458178.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.46 [s] | epoch=1 | batch=1 | val micro-F1=0.4718642392466332
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.29 [s] | epoch=11 | batch=1 | train micro-F1=0.7456545625438515.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.71 [s] | epoch=11 | batch=1 | val micro-F1=0.7413614790677906
# (train_gat_ppi pid=106316) GAT training: time elapsed= 30.91 [s] | epoch=21 | batch=1 | train micro-F1=0.8856615236789294.
# ...
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 253.87 [s] | epoch=161 | batch=1 | val micro-F1=0.9584247264727428
# (train_gat_ppi pid=106316) GAT training: time elapsed= 268.38 [s] | epoch=171 | batch=1 | train micro-F1=0.9912894510749739.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 269.80 [s] | epoch=171 | batch=1 | val micro-F1=0.96002278572935
# (train_gat_ppi pid=106316) GAT training: time elapsed= 284.21 [s] | epoch=181 | batch=1 | train micro-F1=0.9890205434062292.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 285.63 [s] | epoch=181 | batch=1 | val micro-F1=0.9497734831225286
# (train_gat_ppi pid=106316) GAT training: time elapsed= 300.10 [s] | epoch=191 | batch=1 | train micro-F1=0.9890794085580674.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 301.50 [s] | epoch=191 | batch=1 | val micro-F1=0.9641644304068013
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9773971260121533
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [4, 5, 5], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.13 [s] | epoch=1 | batch=1 | train micro-F1=0.3847359118658035.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.48 [s] | epoch=1 | batch=1 | val micro-F1=0.4688292093322747
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.41 [s] | epoch=11 | batch=1 | train micro-F1=0.7727055729457.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.82 [s] | epoch=11 | batch=1 | val micro-F1=0.74056409436148
# (train_gat_ppi pid=106316) GAT training: time elapsed= 31.19 [s] | epoch=21 | batch=1 | train micro-F1=0.9195835737563695.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.61 [s] | epoch=21 | batch=1 | val micro-F1=0.8642636338674391
# (train_gat_ppi pid=106316) GAT training: time elapsed= 47.05 [s] | epoch=31 | batch=1 | train micro-F1=0.9038223097019396.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 48.50 [s] | epoch=31 | batch=1 | val micro-F1=0.8730322366189844
# (train_gat_ppi pid=106316) GAT training: time elapsed= 62.85 [s] | epoch=41 | batch=1 | train micro-F1=0.9301128489408038.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 64.35 [s] | epoch=41 | batch=1 | val micro-F1=0.909672724760163
# (train_gat_ppi pid=106316) GAT training: time elapsed= 78.82 [s] | epoch=51 | batch=1 | train micro-F1=0.9490253833936722.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 80.23 [s] | epoch=51 | batch=1 | val micro-F1=0.9256527962019129
# (train_gat_ppi pid=106316) GAT training: time elapsed= 94.65 [s] | epoch=61 | batch=1 | train micro-F1=0.9743853397510335.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 96.10 [s] | epoch=61 | batch=1 | val micro-F1=0.9413740650164809
# (train_gat_ppi pid=106316) GAT training: time elapsed= 111.20 [s] | epoch=71 | batch=1 | train micro-F1=0.9450848239665813.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 112.64 [s] | epoch=71 | batch=1 | val micro-F1=0.9447366291771179
# (train_gat_ppi pid=106316) GAT training: time elapsed= 127.16 [s] | epoch=81 | batch=1 | train micro-F1=0.9595178080953081.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 128.61 [s] | epoch=81 | batch=1 | val micro-F1=0.9534764970590088
# (train_gat_ppi pid=106316) GAT training: time elapsed= 143.15 [s] | epoch=91 | batch=1 | train micro-F1=0.9812683554550076.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 144.63 [s] | epoch=91 | batch=1 | val micro-F1=0.9552240742222213
# (train_gat_ppi pid=106316) GAT training: time elapsed= 159.16 [s] | epoch=101 | batch=1 | train micro-F1=0.9716090817123035.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 160.61 [s] | epoch=101 | batch=1 | val micro-F1=0.9597580561599834
# (train_gat_ppi pid=106316) GAT training: time elapsed= 175.21 [s] | epoch=111 | batch=1 | train micro-F1=0.9903207546686542.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 176.63 [s] | epoch=111 | batch=1 | val micro-F1=0.9617311499322753
# (train_gat_ppi pid=106316) GAT training: time elapsed= 191.25 [s] | epoch=121 | batch=1 | train micro-F1=0.9727951965728358.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 192.80 [s] | epoch=121 | batch=1 | val micro-F1=0.9589483163511165
# (train_gat_ppi pid=106316) GAT training: time elapsed= 207.43 [s] | epoch=131 | batch=1 | train micro-F1=0.9919824989405445.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 208.89 [s] | epoch=131 | batch=1 | val micro-F1=0.9627158080476075
# (train_gat_ppi pid=106316) GAT training: time elapsed= 223.44 [s] | epoch=141 | batch=1 | train micro-F1=0.9810506017458377.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 224.92 [s] | epoch=141 | batch=1 | val micro-F1=0.9679805352798053
# (train_gat_ppi pid=106316) GAT training: time elapsed= 239.58 [s] | epoch=151 | batch=1 | train micro-F1=0.9885830447852946.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 241.01 [s] | epoch=151 | batch=1 | val micro-F1=0.9683962050416759
# (train_gat_ppi pid=106316) GAT training: time elapsed= 255.73 [s] | epoch=161 | batch=1 | train micro-F1=0.9849914847709709.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 257.21 [s] | epoch=161 | batch=1 | val micro-F1=0.9688249918927683
# (train_gat_ppi pid=106316) GAT training: time elapsed= 271.72 [s] | epoch=171 | batch=1 | train micro-F1=0.9943077888496749.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 273.27 [s] | epoch=171 | batch=1 | val micro-F1=0.9679205271317164
# (train_gat_ppi pid=106316) GAT training: time elapsed= 287.96 [s] | epoch=181 | batch=1 | train micro-F1=0.9915938729274918.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 289.38 [s] | epoch=181 | batch=1 | val micro-F1=0.9660826281945519
# (train_gat_ppi pid=106316) GAT training: time elapsed= 303.93 [s] | epoch=191 | batch=1 | train micro-F1=0.9943841937402749.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 305.42 [s] | epoch=191 | batch=1 | val micro-F1=0.9695787781142846
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9795612621693567
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [5, 5, 5], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.12 [s] | epoch=1 | batch=1 | train micro-F1=0.39492671927846673.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.48 [s] | epoch=1 | batch=1 | val micro-F1=0.4717266598591814
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.47 [s] | epoch=11 | batch=1 | train micro-F1=0.7375714456235999.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.87 [s] | epoch=11 | batch=1 | val micro-F1=0.7620488466757124
# (train_gat_ppi pid=106316) GAT training: time elapsed= 31.23 [s] | epoch=21 | batch=1 | train micro-F1=0.9038325868970711.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.72 [s] | epoch=21 | batch=1 | val micro-F1=0.8086320516265364
# (train_gat_ppi pid=106316) GAT training: time elapsed= 47.12 [s] | epoch=31 | batch=1 | train micro-F1=0.9355261540982264.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 48.53 [s] | epoch=31 | batch=1 | val micro-F1=0.9011865487200708
# (train_gat_ppi pid=106316) GAT training: time elapsed= 62.99 [s] | epoch=41 | batch=1 | train micro-F1=0.9430895430743651.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 64.47 [s] | epoch=41 | batch=1 | val micro-F1=0.9246381105107349
# (train_gat_ppi pid=106316) GAT training: time elapsed= 79.03 [s] | epoch=51 | batch=1 | train micro-F1=0.9637462154197884.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 80.48 [s] | epoch=51 | batch=1 | val micro-F1=0.9403648351648353
# (train_gat_ppi pid=106316) GAT training: time elapsed= 95.06 [s] | epoch=61 | batch=1 | train micro-F1=0.9887558437486346.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 96.49 [s] | epoch=61 | batch=1 | val micro-F1=0.9546312814970115
# (train_gat_ppi pid=106316) GAT training: time elapsed= 111.02 [s] | epoch=71 | batch=1 | train micro-F1=0.9897918351709165.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 112.46 [s] | epoch=71 | batch=1 | val micro-F1=0.9595844830384679
# (train_gat_ppi pid=106316) GAT training: time elapsed= 126.97 [s] | epoch=81 | batch=1 | train micro-F1=0.9920700662146833.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 128.42 [s] | epoch=81 | batch=1 | val micro-F1=0.9610352544351831
# (train_gat_ppi pid=106316) GAT training: time elapsed= 142.96 [s] | epoch=91 | batch=1 | train micro-F1=0.9831394537760625.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 144.37 [s] | epoch=91 | batch=1 | val micro-F1=0.9642427109314526
# (train_gat_ppi pid=106316) GAT training: time elapsed= 158.90 [s] | epoch=101 | batch=1 | train micro-F1=0.9935523539830996.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 160.38 [s] | epoch=101 | batch=1 | val micro-F1=0.96749816930763
# (train_gat_ppi pid=106316) GAT training: time elapsed= 175.02 [s] | epoch=111 | batch=1 | train micro-F1=0.9954302548299039.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 176.44 [s] | epoch=111 | batch=1 | val micro-F1=0.9686987795277284
# (train_gat_ppi pid=106316) GAT training: time elapsed= 190.90 [s] | epoch=121 | batch=1 | train micro-F1=0.9955018917131367.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 192.36 [s] | epoch=121 | batch=1 | val micro-F1=0.9703145023148648
# (train_gat_ppi pid=106316) GAT training: time elapsed= 206.87 [s] | epoch=131 | batch=1 | train micro-F1=0.9955734279353015.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 208.32 [s] | epoch=131 | batch=1 | val micro-F1=0.9695335390359634
# (train_gat_ppi pid=106316) GAT training: time elapsed= 222.91 [s] | epoch=141 | batch=1 | train micro-F1=0.9930958689997925.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 224.32 [s] | epoch=141 | batch=1 | val micro-F1=0.9699656361836102
# (train_gat_ppi pid=106316) GAT training: time elapsed= 238.86 [s] | epoch=151 | batch=1 | train micro-F1=0.996273259045552.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 240.29 [s] | epoch=151 | batch=1 | val micro-F1=0.9725375478381678
# (train_gat_ppi pid=106316) GAT training: time elapsed= 254.74 [s] | epoch=161 | batch=1 | train micro-F1=0.984443786265297.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 256.21 [s] | epoch=161 | batch=1 | val micro-F1=0.9683918945572849
# (train_gat_ppi pid=106316) GAT training: time elapsed= 270.73 [s] | epoch=171 | batch=1 | train micro-F1=0.9922008510548932.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 272.17 [s] | epoch=171 | batch=1 | val micro-F1=0.9729557747375119
# (train_gat_ppi pid=106316) GAT training: time elapsed= 286.62 [s] | epoch=181 | batch=1 | train micro-F1=0.9840901715253648.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 288.11 [s] | epoch=181 | batch=1 | val micro-F1=0.9705752020158137
# (train_gat_ppi pid=106316) GAT training: time elapsed= 302.62 [s] | epoch=191 | batch=1 | train micro-F1=0.8687791689333733.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 304.12 [s] | epoch=191 | batch=1 | val micro-F1=0.8616134227198738
# 2023-05-08 06:10:45,924	INFO tune.py:762 -- Total run time: 8631.49 seconds (8631.32 seconds for the tuning loop).
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9270046420779637

# %%
#@title
from ray import air
scheduler = ASHAScheduler(
    time_attr="training_iteration",
    metric="micro_f1",
    mode="max",
    grace_period=1,
)
# tune_config=tune.TuneConfig(scheduler=scheduler),

stopper = CombinedStopper(
    MaximumIterationStopper(max_iter=10),
    TrialPlateauStopper(metric="micro_f1"),
)

tuner = tune.Tuner(
    tune.with_resources(train_gat_ppi, {"gpu": 1,'cpu': 12}),
    run_config=air.RunConfig(
      name="gnn_exp_heads_per_layer",
      stop=stopper,
      verbose=1,
  ),
    tune_config=tune.TuneConfig(scheduler=scheduler, num_samples=1),
    param_space={
        # distribution for resampling
        # GNNs, contrary to CNNs, are often shallow (it ultimately depends on the graph properties)
        'num_of_epochs': 200,
         'patience_period': 50,
         'lr': 0.005,
         'weight_decay': 0,
         'should_test': True,
         'force_cpu': False,
         'dataset_name': 'PPI',
         'batch_size': 2,
         'should_visualize': False,
         'enable_tensorboard': False,
         'console_log_freq': 10,
         'checkpoint_freq': 5,
         'ppi_load_test_only': False,
        "num_of_layers": 3 , # PPI has got 42% of nodes with all 0 features - that's why 3 layers are useful
        'num_heads_per_layer1': tune.grid_search(list(range(3, 6))),
        "num_heads_per_layer2": tune.grid_search(list(range(3, 6))),  # other values may give even better results from the reported ones
        'num_heads_per_layer3': tune.grid_search(list(range(3, 6))),
        "num_features_per_layer": [PPI_NUM_INPUT_FEATURES, 64, 64, PPI_NUM_CLASSES],  # 64 would also give ~0.975 uF1!
        "add_skip_connection": True,  # skip connection is very important! (keep it otherwise micro-F1 is almost 0)
        "bias": True,  # bias doesn't matter that much
        "dropout": 0.,  # dropout hurts the performance (best to keep it at 0)
        #         "lr": lambda: np.random.uniform(0.0001, 1),
        #         # allow perturbations within this set of categorical values
        #         "momentum": [0.8, 0.9, 0.99],
    }
)
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-05-08 06:10:45</td></tr>
# <tr><td>Running for: </td><td>02:23:51.33        </td></tr>
# <tr><td>Memory:      </td><td>5.4/83.5 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=14<br>Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: 0.9776308807383904<br>Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/49.67 GiB heap, 0.0/24.84 GiB objects (0.0/1.0 accelerator_type:A100)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name               </th><th>status    </th><th>loc               </th><th style="text-align: right;">  num_heads_per_layer1</th><th style="text-align: right;">  num_heads_per_layer2</th><th style="text-align: right;">  num_heads_per_layer3</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  micro_f1</th></tr>
# </thead>
# <tbody>
# <tr><td>train_gat_ppi_f9577_00000</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         328.027</td><td style="text-align: right;">  0.956045</td></tr>
# <tr><td>train_gat_ppi_f9577_00001</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         327.455</td><td style="text-align: right;">  0.972534</td></tr>
# <tr><td>train_gat_ppi_f9577_00002</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         331.971</td><td style="text-align: right;">  0.974586</td></tr>
# <tr><td>train_gat_ppi_f9577_00003</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         327.032</td><td style="text-align: right;">  0.862875</td></tr>
# <tr><td>train_gat_ppi_f9577_00004</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         305.342</td><td style="text-align: right;">  0.927491</td></tr>
# <tr><td>train_gat_ppi_f9577_00005</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         329.335</td><td style="text-align: right;">  0.906079</td></tr>
# <tr><td>train_gat_ppi_f9577_00006</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         330.507</td><td style="text-align: right;">  0.977865</td></tr>
# <tr><td>train_gat_ppi_f9577_00007</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         329.201</td><td style="text-align: right;">  0.978031</td></tr>
# <tr><td>train_gat_ppi_f9577_00008</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     3</td><td style="text-align: right;">     1</td><td style="text-align: right;">         177.317</td><td style="text-align: right;">  0.942868</td></tr>
# <tr><td>train_gat_ppi_f9577_00009</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         247.575</td><td style="text-align: right;">  0.869984</td></tr>
# <tr><td>train_gat_ppi_f9577_00010</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         325.861</td><td style="text-align: right;">  0.872136</td></tr>
# <tr><td>train_gat_ppi_f9577_00011</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         325.529</td><td style="text-align: right;">  0.971165</td></tr>
# <tr><td>train_gat_ppi_f9577_00012</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         326.831</td><td style="text-align: right;">  0.970779</td></tr>
# <tr><td>train_gat_ppi_f9577_00013</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         325.944</td><td style="text-align: right;">  0.975721</td></tr>
# <tr><td>train_gat_ppi_f9577_00014</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         329.929</td><td style="text-align: right;">  0.982132</td></tr>
# <tr><td>train_gat_ppi_f9577_00015</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     3</td><td style="text-align: right;">                     5</td><td style="text-align: right;">                     4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         328.077</td><td style="text-align: right;">  0.976604</td></tr>
# <tr><td>train_gat_ppi_f9577_00016</td><td>TERMINATED</td><td>172.28.0.12:106316</td><td style="text-align: right;">                     4</td><td style="text-align: right;">                     5</td><td style="text-align: right;">
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [3, 3, 3], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.41 [s] | epoch=1 | batch=1 | train micro-F1=0.3649627973361994.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.71 [s] | epoch=1 | batch=1 | val micro-F1=0.41822505322945075
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.37 [s] | epoch=11 | batch=1 | train micro-F1=0.7194236952845541.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.78 [s] | epoch=11 | batch=1 | val micro-F1=0.6883074626294332
# (train_gat_ppi pid=106316) GAT training: time elapsed= 30.99 [s] | epoch=21 | batch=1 | train micro-F1=0.8143812835915271.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.38 [s] | epoch=21 | batch=1 | val micro-F1=0.8104263494804271
# (train_gat_ppi pid=106316) GAT training: time elapsed= 46.62 [s] | epoch=31 | batch=1 | train micro-F1=0.8430481234479014.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 48.05 [s] | epoch=31 | batch=1 | val micro-F1=0.8206348036423818
# (train_gat_ppi pid=106316) GAT training: time elapsed= 62.40 [s] | epoch=41 | batch=1 | train micro-F1=0.8841213532510661.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 63.80 [s] | epoch=41 | batch=1 | val micro-F1=0.859802496007993
# (train_gat_ppi pid=106316) GAT training: time elapsed= 77.93 [s] | epoch=51 | batch=1 | train micro-F1=0.880086382445232.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 79.42 [s] | epoch=51 | batch=1 | val micro-F1=0.8792832393970684
# (train_gat_ppi pid=106316) GAT training: time elapsed= 93.73 [s] | epoch=61 | batch=1 | train micro-F1=0.9400462247973671.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 95.13 [s] | epoch=61 | batch=1 | val micro-F1=0.887658199443497
# (train_gat_ppi pid=106316) GAT training: time elapsed= 109.41 [s] | epoch=71 | batch=1 | train micro-F1=0.9333110555855124.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 110.89 [s] | epoch=71 | batch=1 | val micro-F1=0.9043409749958966
# (train_gat_ppi pid=106316) GAT training: time elapsed= 125.35 [s] | epoch=81 | batch=1 | train micro-F1=0.9250150422953953.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 126.73 [s] | epoch=81 | batch=1 | val micro-F1=0.9087738321906405
# (train_gat_ppi pid=106316) GAT training: time elapsed= 141.01 [s] | epoch=91 | batch=1 | train micro-F1=0.9513948192428124.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 142.46 [s] | epoch=91 | batch=1 | val micro-F1=0.917924142669531
# (train_gat_ppi pid=106316) GAT training: time elapsed= 156.75 [s] | epoch=101 | batch=1 | train micro-F1=0.9247989065688982.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 158.18 [s] | epoch=101 | batch=1 | val micro-F1=0.9198579452520488
# (train_gat_ppi pid=106316) GAT training: time elapsed= 172.50 [s] | epoch=111 | batch=1 | train micro-F1=0.9612070943465493.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 173.93 [s] | epoch=111 | batch=1 | val micro-F1=0.9263510584298595
# (train_gat_ppi pid=106316) GAT training: time elapsed= 188.23 [s] | epoch=121 | batch=1 | train micro-F1=0.9313530571324631.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 189.59 [s] | epoch=121 | batch=1 | val micro-F1=0.9280317657710725
# (train_gat_ppi pid=106316) GAT training: time elapsed= 203.84 [s] | epoch=131 | batch=1 | train micro-F1=0.952612819043982.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 205.22 [s] | epoch=131 | batch=1 | val micro-F1=0.9318120360435802
# (train_gat_ppi pid=106316) GAT training: time elapsed= 219.49 [s] | epoch=141 | batch=1 | train micro-F1=0.9482763281082981.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 220.88 [s] | epoch=141 | batch=1 | val micro-F1=0.931473248505289
# (train_gat_ppi pid=106316) GAT training: time elapsed= 235.07 [s] | epoch=151 | batch=1 | train micro-F1=0.9675882708253254.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 236.50 [s] | epoch=151 | batch=1 | val micro-F1=0.9362428941466892
# (train_gat_ppi pid=106316) GAT training: time elapsed= 250.81 [s] | epoch=161 | batch=1 | train micro-F1=0.9465684444089504.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 252.17 [s] | epoch=161 | batch=1 | val micro-F1=0.9320500078464193
# (train_gat_ppi pid=106316) GAT training: time elapsed= 267.10 [s] | epoch=171 | batch=1 | train micro-F1=0.9625225339194788.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 268.48 [s] | epoch=171 | batch=1 | val micro-F1=0.9388121275902894
# (train_gat_ppi pid=106316) GAT training: time elapsed= 282.74 [s] | epoch=181 | batch=1 | train micro-F1=0.9683864133252191.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 284.23 [s] | epoch=181 | batch=1 | val micro-F1=0.9350288405333568
# (train_gat_ppi pid=106316) GAT training: time elapsed= 298.54 [s] | epoch=191 | batch=1 | train micro-F1=0.9752931914346386.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 299.97 [s] | epoch=191 | batch=1 | val micro-F1=0.9405385771707523
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9560450654175416
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [4, 3, 3], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.13 [s] | epoch=1 | batch=1 | train micro-F1=0.3725199248190658.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.48 [s] | epoch=1 | batch=1 | val micro-F1=0.5040021737125365
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.27 [s] | epoch=11 | batch=1 | train micro-F1=0.7698885597597434.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.70 [s] | epoch=11 | batch=1 | val micro-F1=0.726961819969535
# (train_gat_ppi pid=106316) GAT training: time elapsed= 30.82 [s] | epoch=21 | batch=1 | train micro-F1=0.8828672887934594.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.25 [s] | epoch=21 | batch=1 | val micro-F1=0.8442474841398595
# (train_gat_ppi pid=106316) GAT training: time elapsed= 46.50 [s] | epoch=31 | batch=1 | train micro-F1=0.9326664445026303.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 47.94 [s] | epoch=31 | batch=1 | val micro-F1=0.8862578004868947
# (train_gat_ppi pid=106316) GAT training: time elapsed= 62.16 [s] | epoch=41 | batch=1 | train micro-F1=0.9165260676550478.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 63.66 [s] | epoch=41 | batch=1 | val micro-F1=0.9119106972490778
# (train_gat_ppi pid=106316) GAT training: time elapsed= 77.84 [s] | epoch=51 | batch=1 | train micro-F1=0.915362555593952.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 79.35 [s] | epoch=51 | batch=1 | val micro-F1=0.8937714552979695
# (train_gat_ppi pid=106316) GAT training: time elapsed= 93.62 [s] | epoch=61 | batch=1 | train micro-F1=0.9406055827748682.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 95.06 [s] | epoch=61 | batch=1 | val micro-F1=0.9107160439800885
# (train_gat_ppi pid=106316) GAT training: time elapsed= 109.30 [s] | epoch=71 | batch=1 | train micro-F1=0.9347853921034244.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 110.76 [s] | epoch=71 | batch=1 | val micro-F1=0.9217031480623813
# (train_gat_ppi pid=106316) GAT training: time elapsed= 125.01 [s] | epoch=81 | batch=1 | train micro-F1=0.9443267193219033.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 126.46 [s] | epoch=81 | batch=1 | val micro-F1=0.9304065496672311
# (train_gat_ppi pid=106316) GAT training: time elapsed= 140.77 [s] | epoch=91 | batch=1 | train micro-F1=0.9694697533273917.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 142.18 [s] | epoch=91 | batch=1 | val micro-F1=0.9323341706164268
# (train_gat_ppi pid=106316) GAT training: time elapsed= 156.41 [s] | epoch=101 | batch=1 | train micro-F1=0.9660026504993164.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 157.80 [s] | epoch=101 | batch=1 | val micro-F1=0.93649980067202
# (train_gat_ppi pid=106316) GAT training: time elapsed= 172.02 [s] | epoch=111 | batch=1 | train micro-F1=0.976347191472406.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 173.44 [s] | epoch=111 | batch=1 | val micro-F1=0.9411537437861135
# (train_gat_ppi pid=106316) GAT training: time elapsed= 187.66 [s] | epoch=121 | batch=1 | train micro-F1=0.9758100967038118.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 189.08 [s] | epoch=121 | batch=1 | val micro-F1=0.9447733340864605
# (train_gat_ppi pid=106316) GAT training: time elapsed= 203.27 [s] | epoch=131 | batch=1 | train micro-F1=0.9644019076239628.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 204.68 [s] | epoch=131 | batch=1 | val micro-F1=0.9482888287618536
# (train_gat_ppi pid=106316) GAT training: time elapsed= 219.04 [s] | epoch=141 | batch=1 | train micro-F1=0.9576983797257997.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 220.41 [s] | epoch=141 | batch=1 | val micro-F1=0.9301204068183032
# (train_gat_ppi pid=106316) GAT training: time elapsed= 234.79 [s] | epoch=151 | batch=1 | train micro-F1=0.9857712892022097.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 236.23 [s] | epoch=151 | batch=1 | val micro-F1=0.9526533948274855
# (train_gat_ppi pid=106316) GAT training: time elapsed= 250.61 [s] | epoch=161 | batch=1 | train micro-F1=0.9818177752767955.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 252.11 [s] | epoch=161 | batch=1 | val micro-F1=0.9545148014939827
# (train_gat_ppi pid=106316) GAT training: time elapsed= 266.51 [s] | epoch=171 | batch=1 | train micro-F1=0.9626659876365962.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 267.93 [s] | epoch=171 | batch=1 | val micro-F1=0.9561185511950236
# (train_gat_ppi pid=106316) GAT training: time elapsed= 282.28 [s] | epoch=181 | batch=1 | train micro-F1=0.9838686397283718.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 283.74 [s] | epoch=181 | batch=1 | val micro-F1=0.9551148001356904
# (train_gat_ppi pid=106316) GAT training: time elapsed= 298.09 [s] | epoch=191 | batch=1 | train micro-F1=0.9707378276648275.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 299.55 [s] | epoch=191 | batch=1 | val micro-F1=0.9493413877736568
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9725342033309101
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [5, 3, 3], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.17 [s] | epoch=1 | batch=1 | train micro-F1=0.3814715169377974.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.48 [s] | epoch=1 | batch=1 | val micro-F1=0.460934007502492
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.32 [s] | epoch=11 | batch=1 | train micro-F1=0.728990415035973.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.71 [s] | epoch=11 | batch=1 | val micro-F1=0.7352154641941722
# (train_gat_ppi pid=106316) GAT training: time elapsed= 30.93 [s] | epoch=21 | batch=1 | train micro-F1=0.866687730063685.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.40 [s] | epoch=21 | batch=1 | val micro-F1=0.8049621073817136
# (train_gat_ppi pid=106316) GAT training: time elapsed= 46.72 [s] | epoch=31 | batch=1 | train micro-F1=0.9344824269950146.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 48.16 [s] | epoch=31 | batch=1 | val micro-F1=0.8908716056032103
# (train_gat_ppi pid=106316) GAT training: time elapsed= 62.52 [s] | epoch=41 | batch=1 | train micro-F1=0.9487446648855071.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 63.91 [s] | epoch=41 | batch=1 | val micro-F1=0.9049119189171402
# (train_gat_ppi pid=106316) GAT training: time elapsed= 78.23 [s] | epoch=51 | batch=1 | train micro-F1=0.959957273516256.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 79.72 [s] | epoch=51 | batch=1 | val micro-F1=0.9316832500184581
# (train_gat_ppi pid=106316) GAT training: time elapsed= 94.07 [s] | epoch=61 | batch=1 | train micro-F1=0.9744606798883855.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 95.52 [s] | epoch=61 | batch=1 | val micro-F1=0.9388233806605758
# (train_gat_ppi pid=106316) GAT training: time elapsed= 109.81 [s] | epoch=71 | batch=1 | train micro-F1=0.9706443063890421.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 111.29 [s] | epoch=71 | batch=1 | val micro-F1=0.946499954525178
# (train_gat_ppi pid=106316) GAT training: time elapsed= 125.59 [s] | epoch=81 | batch=1 | train micro-F1=0.9758806414091626.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 127.05 [s] | epoch=81 | batch=1 | val micro-F1=0.9450405715312803
# (train_gat_ppi pid=106316) GAT training: time elapsed= 141.34 [s] | epoch=91 | batch=1 | train micro-F1=0.9555606372436923.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 142.77 [s] | epoch=91 | batch=1 | val micro-F1=0.924385846782076
# (train_gat_ppi pid=106316) GAT training: time elapsed= 156.99 [s] | epoch=101 | batch=1 | train micro-F1=0.95156117369061.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 158.46 [s] | epoch=101 | batch=1 | val micro-F1=0.951690354599881
# (train_gat_ppi pid=106316) GAT training: time elapsed= 172.74 [s] | epoch=111 | batch=1 | train micro-F1=0.9708575956619094.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 174.14 [s] | epoch=111 | batch=1 | val micro-F1=0.9550817744288856
# (train_gat_ppi pid=106316) GAT training: time elapsed= 188.48 [s] | epoch=121 | batch=1 | train micro-F1=0.9848551266295877.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 189.89 [s] | epoch=121 | batch=1 | val micro-F1=0.9461759877188118
# (train_gat_ppi pid=106316) GAT training: time elapsed= 204.27 [s] | epoch=131 | batch=1 | train micro-F1=0.992442459635864.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 205.69 [s] | epoch=131 | batch=1 | val micro-F1=0.9624564689230184
# (train_gat_ppi pid=106316) GAT training: time elapsed= 220.98 [s] | epoch=141 | batch=1 | train micro-F1=0.9294861985446601.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 222.51 [s] | epoch=141 | batch=1 | val micro-F1=0.8535212224877943
# (train_gat_ppi pid=106316) GAT training: time elapsed= 237.13 [s] | epoch=151 | batch=1 | train micro-F1=0.9796432481663421.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 238.65 [s] | epoch=151 | batch=1 | val micro-F1=0.960416057207866
# (train_gat_ppi pid=106316) GAT training: time elapsed= 253.30 [s] | epoch=161 | batch=1 | train micro-F1=0.993965514800205.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 254.77 [s] | epoch=161 | batch=1 | val micro-F1=0.9650746801649568
# (train_gat_ppi pid=106316) GAT training: time elapsed= 269.39 [s] | epoch=171 | batch=1 | train micro-F1=0.9817920980748749.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 270.95 [s] | epoch=171 | batch=1 | val micro-F1=0.9646741824922938
# (train_gat_ppi pid=106316) GAT training: time elapsed= 285.64 [s] | epoch=181 | batch=1 | train micro-F1=0.9901926436005173.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 287.08 [s] | epoch=181 | batch=1 | val micro-F1=0.9615572338676531
# (train_gat_ppi pid=106316) GAT training: time elapsed= 301.84 [s] | epoch=191 | batch=1 | train micro-F1=0.9869732258215822.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 303.25 [s] | epoch=191 | batch=1 | val micro-F1=0.9661687417138465
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9745859002564634
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [3, 4, 3], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.16 [s] | epoch=1 | batch=1 | train micro-F1=0.3719373896205187.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.46 [s] | epoch=1 | batch=1 | val micro-F1=0.4516315771725324
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.19 [s] | epoch=11 | batch=1 | train micro-F1=0.6869615163699024.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.55 [s] | epoch=11 | batch=1 | val micro-F1=0.7230849545818397
# (train_gat_ppi pid=106316) GAT training: time elapsed= 30.65 [s] | epoch=21 | batch=1 | train micro-F1=0.8728109429704994.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.08 [s] | epoch=21 | batch=1 | val micro-F1=0.8347938880949765
# (train_gat_ppi pid=106316) GAT training: time elapsed= 46.31 [s] | epoch=31 | batch=1 | train micro-F1=0.9164143561830244.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 47.72 [s] | epoch=31 | batch=1 | val micro-F1=0.8685094555950624
# (train_gat_ppi pid=106316) GAT training: time elapsed= 61.99 [s] | epoch=41 | batch=1 | train micro-F1=0.9196848226765448.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 63.44 [s] | epoch=41 | batch=1 | val micro-F1=0.9085361417494692
# (train_gat_ppi pid=106316) GAT training: time elapsed= 77.71 [s] | epoch=51 | batch=1 | train micro-F1=0.8919238576246264.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 79.12 [s] | epoch=51 | batch=1 | val micro-F1=0.8846930334783283
# (train_gat_ppi pid=106316) GAT training: time elapsed= 93.35 [s] | epoch=61 | batch=1 | train micro-F1=0.9334285530550976.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 94.78 [s] | epoch=61 | batch=1 | val micro-F1=0.9033884127891452
# (train_gat_ppi pid=106316) GAT training: time elapsed= 108.88 [s] | epoch=71 | batch=1 | train micro-F1=0.9122910564940923.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 110.36 [s] | epoch=71 | batch=1 | val micro-F1=0.91911621019537
# (train_gat_ppi pid=106316) GAT training: time elapsed= 124.53 [s] | epoch=81 | batch=1 | train micro-F1=0.9314170177752602.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 125.98 [s] | epoch=81 | batch=1 | val micro-F1=0.9259050401816722
# (train_gat_ppi pid=106316) GAT training: time elapsed= 140.14 [s] | epoch=91 | batch=1 | train micro-F1=0.9615661332553639.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 141.60 [s] | epoch=91 | batch=1 | val micro-F1=0.9311043829671114
# (train_gat_ppi pid=106316) GAT training: time elapsed= 155.89 [s] | epoch=101 | batch=1 | train micro-F1=0.949729300153976.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 157.30 [s] | epoch=101 | batch=1 | val micro-F1=0.9323176001438931
# (train_gat_ppi pid=106316) GAT training: time elapsed= 171.60 [s] | epoch=111 | batch=1 | train micro-F1=0.9700527542224985.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 173.05 [s] | epoch=111 | batch=1 | val micro-F1=0.9357119259993393
# (train_gat_ppi pid=106316) GAT training: time elapsed= 187.59 [s] | epoch=121 | batch=1 | train micro-F1=0.9843378611169001.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 189.02 [s] | epoch=121 | batch=1 | val micro-F1=0.9405684754521965
# (train_gat_ppi pid=106316) GAT training: time elapsed= 203.33 [s] | epoch=131 | batch=1 | train micro-F1=0.9634826735848787.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 204.77 [s] | epoch=131 | batch=1 | val micro-F1=0.9426819456826632
# (train_gat_ppi pid=106316) GAT training: time elapsed= 219.07 [s] | epoch=141 | batch=1 | train micro-F1=0.9795901820823939.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 220.49 [s] | epoch=141 | batch=1 | val micro-F1=0.9481772131681808
# (train_gat_ppi pid=106316) GAT training: time elapsed= 234.86 [s] | epoch=151 | batch=1 | train micro-F1=0.9681896210220521.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 236.24 [s] | epoch=151 | batch=1 | val micro-F1=0.9468903577134608
# (train_gat_ppi pid=106316) GAT training: time elapsed= 250.52 [s] | epoch=161 | batch=1 | train micro-F1=0.9854369627712478.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 251.94 [s] | epoch=161 | batch=1 | val micro-F1=0.9475739580495779
# (train_gat_ppi pid=106316) GAT training: time elapsed= 266.30 [s] | epoch=171 | batch=1 | train micro-F1=0.986049930636541.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 267.72 [s] | epoch=171 | batch=1 | val micro-F1=0.9520321243411155
# (train_gat_ppi pid=106316) GAT training: time elapsed= 282.07 [s] | epoch=181 | batch=1 | train micro-F1=0.9780817326583917.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 283.50 [s] | epoch=181 | batch=1 | val micro-F1=0.9527938092514602
# (train_gat_ppi pid=106316) GAT training: time elapsed= 297.77 [s] | epoch=191 | batch=1 | train micro-F1=0.8260188251154419.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 299.20 [s] | epoch=191 | batch=1 | val micro-F1=0.7917674509653916
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.8628751614224888
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [4, 4, 3], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.13 [s] | epoch=1 | batch=1 | train micro-F1=0.3916259642648948.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.47 [s] | epoch=1 | batch=1 | val micro-F1=0.4767347850600513
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.29 [s] | epoch=11 | batch=1 | train micro-F1=0.7297499254434024.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.70 [s] | epoch=11 | batch=1 | val micro-F1=0.7172829888287816
# (train_gat_ppi pid=106316) GAT training: time elapsed= 30.96 [s] | epoch=21 | batch=1 | train micro-F1=0.8772381576620161.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.37 [s] | epoch=21 | batch=1 | val micro-F1=0.8348935271097065
# (train_gat_ppi pid=106316) GAT training: time elapsed= 46.78 [s] | epoch=31 | batch=1 | train micro-F1=0.8966670484480586.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 48.21 [s] | epoch=31 | batch=1 | val micro-F1=0.8966634727335316
# (train_gat_ppi pid=106316) GAT training: time elapsed= 62.50 [s] | epoch=41 | batch=1 | train micro-F1=0.9666702657854509.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 63.94 [s] | epoch=41 | batch=1 | val micro-F1=0.9169394723410248
# (train_gat_ppi pid=106316) GAT training: time elapsed= 78.29 [s] | epoch=51 | batch=1 | train micro-F1=0.9548334942626817.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 79.66 [s] | epoch=51 | batch=1 | val micro-F1=0.9377548235029053
# (train_gat_ppi pid=106316) GAT training: time elapsed= 93.87 [s] | epoch=61 | batch=1 | train micro-F1=0.9735390393057424.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 95.26 [s] | epoch=61 | batch=1 | val micro-F1=0.9489561322499227
# (train_gat_ppi pid=106316) GAT training: time elapsed= 109.47 [s] | epoch=71 | batch=1 | train micro-F1=0.982324742655346.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 110.89 [s] | epoch=71 | batch=1 | val micro-F1=0.9542503677311098
# (train_gat_ppi pid=106316) GAT training: time elapsed= 125.19 [s] | epoch=81 | batch=1 | train micro-F1=0.9669551203292313.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 126.57 [s] | epoch=81 | batch=1 | val micro-F1=0.9522545781259906
# (train_gat_ppi pid=106316) GAT training: time elapsed= 140.91 [s] | epoch=91 | batch=1 | train micro-F1=0.9745781064648861.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 142.35 [s] | epoch=91 | batch=1 | val micro-F1=0.9588225373308598
# (train_gat_ppi pid=106316) GAT training: time elapsed= 157.41 [s] | epoch=101 | batch=1 | train micro-F1=0.9912013517255408.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 158.86 [s] | epoch=101 | batch=1 | val micro-F1=0.9587768522577816
# (train_gat_ppi pid=106316) GAT training: time elapsed= 173.40 [s] | epoch=111 | batch=1 | train micro-F1=0.9885822575447911.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 174.80 [s] | epoch=111 | batch=1 | val micro-F1=0.9664827621933846
# (train_gat_ppi pid=106316) GAT training: time elapsed= 189.26 [s] | epoch=121 | batch=1 | train micro-F1=0.975298619969848.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 190.75 [s] | epoch=121 | batch=1 | val micro-F1=0.9524585841719031
# (train_gat_ppi pid=106316) GAT training: time elapsed= 205.25 [s] | epoch=131 | batch=1 | train micro-F1=0.9946371622443528.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 206.70 [s] | epoch=131 | batch=1 | val micro-F1=0.9665979078285614
# (train_gat_ppi pid=106316) GAT training: time elapsed= 221.17 [s] | epoch=141 | batch=1 | train micro-F1=0.7403988648904304.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 222.67 [s] | epoch=141 | batch=1 | val micro-F1=0.703239267224778
# (train_gat_ppi pid=106316) GAT training: time elapsed= 237.06 [s] | epoch=151 | batch=1 | train micro-F1=0.866236405175772.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 238.56 [s] | epoch=151 | batch=1 | val micro-F1=0.8445056993714712
# (train_gat_ppi pid=106316) GAT training: time elapsed= 253.12 [s] | epoch=161 | batch=1 | train micro-F1=0.8833204103542884.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 254.52 [s] | epoch=161 | batch=1 | val micro-F1=0.873856158550747
# (train_gat_ppi pid=106316) GAT training: time elapsed= 269.00 [s] | epoch=171 | batch=1 | train micro-F1=0.9300594782502206.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 270.43 [s] | epoch=171 | batch=1 | val micro-F1=0.8898207874298975
# (train_gat_ppi pid=106316) GAT training: time elapsed= 284.85 [s] | epoch=181 | batch=1 | train micro-F1=0.9073595822549049.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 286.29 [s] | epoch=181 | batch=1 | val micro-F1=0.9006753360288493
# (train_gat_ppi pid=106316) Stopping the training, the universe has no more patience for this training.
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9274907028049165
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [5, 4, 3], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.16 [s] | epoch=1 | batch=1 | train micro-F1=0.3802298693458178.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.46 [s] | epoch=1 | batch=1 | val micro-F1=0.4718642392466332
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.29 [s] | epoch=11 | batch=1 | train micro-F1=0.7456545625438515.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.71 [s] | epoch=11 | batch=1 | val micro-F1=0.7413614790677906
# (train_gat_ppi pid=106316) GAT training: time elapsed= 30.91 [s] | epoch=21 | batch=1 | train micro-F1=0.8856615236789294.
# ...
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 253.87 [s] | epoch=161 | batch=1 | val micro-F1=0.9584247264727428
# (train_gat_ppi pid=106316) GAT training: time elapsed= 268.38 [s] | epoch=171 | batch=1 | train micro-F1=0.9912894510749739.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 269.80 [s] | epoch=171 | batch=1 | val micro-F1=0.96002278572935
# (train_gat_ppi pid=106316) GAT training: time elapsed= 284.21 [s] | epoch=181 | batch=1 | train micro-F1=0.9890205434062292.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 285.63 [s] | epoch=181 | batch=1 | val micro-F1=0.9497734831225286
# (train_gat_ppi pid=106316) GAT training: time elapsed= 300.10 [s] | epoch=191 | batch=1 | train micro-F1=0.9890794085580674.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 301.50 [s] | epoch=191 | batch=1 | val micro-F1=0.9641644304068013
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9773971260121533
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [4, 5, 5], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.13 [s] | epoch=1 | batch=1 | train micro-F1=0.3847359118658035.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.48 [s] | epoch=1 | batch=1 | val micro-F1=0.4688292093322747
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.41 [s] | epoch=11 | batch=1 | train micro-F1=0.7727055729457.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.82 [s] | epoch=11 | batch=1 | val micro-F1=0.74056409436148
# (train_gat_ppi pid=106316) GAT training: time elapsed= 31.19 [s] | epoch=21 | batch=1 | train micro-F1=0.9195835737563695.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.61 [s] | epoch=21 | batch=1 | val micro-F1=0.8642636338674391
# (train_gat_ppi pid=106316) GAT training: time elapsed= 47.05 [s] | epoch=31 | batch=1 | train micro-F1=0.9038223097019396.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 48.50 [s] | epoch=31 | batch=1 | val micro-F1=0.8730322366189844
# (train_gat_ppi pid=106316) GAT training: time elapsed= 62.85 [s] | epoch=41 | batch=1 | train micro-F1=0.9301128489408038.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 64.35 [s] | epoch=41 | batch=1 | val micro-F1=0.909672724760163
# (train_gat_ppi pid=106316) GAT training: time elapsed= 78.82 [s] | epoch=51 | batch=1 | train micro-F1=0.9490253833936722.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 80.23 [s] | epoch=51 | batch=1 | val micro-F1=0.9256527962019129
# (train_gat_ppi pid=106316) GAT training: time elapsed= 94.65 [s] | epoch=61 | batch=1 | train micro-F1=0.9743853397510335.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 96.10 [s] | epoch=61 | batch=1 | val micro-F1=0.9413740650164809
# (train_gat_ppi pid=106316) GAT training: time elapsed= 111.20 [s] | epoch=71 | batch=1 | train micro-F1=0.9450848239665813.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 112.64 [s] | epoch=71 | batch=1 | val micro-F1=0.9447366291771179
# (train_gat_ppi pid=106316) GAT training: time elapsed= 127.16 [s] | epoch=81 | batch=1 | train micro-F1=0.9595178080953081.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 128.61 [s] | epoch=81 | batch=1 | val micro-F1=0.9534764970590088
# (train_gat_ppi pid=106316) GAT training: time elapsed= 143.15 [s] | epoch=91 | batch=1 | train micro-F1=0.9812683554550076.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 144.63 [s] | epoch=91 | batch=1 | val micro-F1=0.9552240742222213
# (train_gat_ppi pid=106316) GAT training: time elapsed= 159.16 [s] | epoch=101 | batch=1 | train micro-F1=0.9716090817123035.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 160.61 [s] | epoch=101 | batch=1 | val micro-F1=0.9597580561599834
# (train_gat_ppi pid=106316) GAT training: time elapsed= 175.21 [s] | epoch=111 | batch=1 | train micro-F1=0.9903207546686542.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 176.63 [s] | epoch=111 | batch=1 | val micro-F1=0.9617311499322753
# (train_gat_ppi pid=106316) GAT training: time elapsed= 191.25 [s] | epoch=121 | batch=1 | train micro-F1=0.9727951965728358.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 192.80 [s] | epoch=121 | batch=1 | val micro-F1=0.9589483163511165
# (train_gat_ppi pid=106316) GAT training: time elapsed= 207.43 [s] | epoch=131 | batch=1 | train micro-F1=0.9919824989405445.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 208.89 [s] | epoch=131 | batch=1 | val micro-F1=0.9627158080476075
# (train_gat_ppi pid=106316) GAT training: time elapsed= 223.44 [s] | epoch=141 | batch=1 | train micro-F1=0.9810506017458377.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 224.92 [s] | epoch=141 | batch=1 | val micro-F1=0.9679805352798053
# (train_gat_ppi pid=106316) GAT training: time elapsed= 239.58 [s] | epoch=151 | batch=1 | train micro-F1=0.9885830447852946.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 241.01 [s] | epoch=151 | batch=1 | val micro-F1=0.9683962050416759
# (train_gat_ppi pid=106316) GAT training: time elapsed= 255.73 [s] | epoch=161 | batch=1 | train micro-F1=0.9849914847709709.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 257.21 [s] | epoch=161 | batch=1 | val micro-F1=0.9688249918927683
# (train_gat_ppi pid=106316) GAT training: time elapsed= 271.72 [s] | epoch=171 | batch=1 | train micro-F1=0.9943077888496749.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 273.27 [s] | epoch=171 | batch=1 | val micro-F1=0.9679205271317164
# (train_gat_ppi pid=106316) GAT training: time elapsed= 287.96 [s] | epoch=181 | batch=1 | train micro-F1=0.9915938729274918.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 289.38 [s] | epoch=181 | batch=1 | val micro-F1=0.9660826281945519
# (train_gat_ppi pid=106316) GAT training: time elapsed= 303.93 [s] | epoch=191 | batch=1 | train micro-F1=0.9943841937402749.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 305.42 [s] | epoch=191 | batch=1 | val micro-F1=0.9695787781142846
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9795612621693567
# (train_gat_ppi pid=106316) {'num_heads_per_layer': [5, 5, 5], 'num_of_layers': 3, 'num_features_per_layer': [50, 64, 64, 121]}
# (train_gat_ppi pid=106316) Loading train graph 1 to CPU. It has 1767 nodes and 34085 edges.
# (train_gat_ppi pid=106316) Loading train graph 2 to CPU. It has 1377 nodes and 31081 edges.
# (train_gat_ppi pid=106316) Loading train graph 3 to CPU. It has 2263 nodes and 61907 edges.
# (train_gat_ppi pid=106316) Loading train graph 4 to CPU. It has 2339 nodes and 67769 edges.
# (train_gat_ppi pid=106316) Loading train graph 5 to CPU. It has 1578 nodes and 37740 edges.
# (train_gat_ppi pid=106316) Loading train graph 6 to CPU. It has 1021 nodes and 19237 edges.
# (train_gat_ppi pid=106316) Loading train graph 7 to CPU. It has 1823 nodes and 46153 edges.
# (train_gat_ppi pid=106316) Loading train graph 8 to CPU. It has 2488 nodes and 72878 edges.
# (train_gat_ppi pid=106316) Loading train graph 9 to CPU. It has 591 nodes and 8299 edges.
# (train_gat_ppi pid=106316) Loading train graph 10 to CPU. It has 3312 nodes and 109510 edges.
# (train_gat_ppi pid=106316) Loading train graph 11 to CPU. It has 2401 nodes and 66619 edges.
# (train_gat_ppi pid=106316) Loading train graph 12 to CPU. It has 1878 nodes and 48146 edges.
# (train_gat_ppi pid=106316) Loading train graph 13 to CPU. It has 1819 nodes and 47587 edges.
# (train_gat_ppi pid=106316) Loading train graph 14 to CPU. It has 3480 nodes and 110234 edges.
# (train_gat_ppi pid=106316) Loading train graph 15 to CPU. It has 2794 nodes and 88112 edges.
# (train_gat_ppi pid=106316) Loading train graph 16 to CPU. It has 2326 nodes and 62188 edges.
# (train_gat_ppi pid=106316) Loading train graph 17 to CPU. It has 2650 nodes and 79714 edges.
# (train_gat_ppi pid=106316) Loading train graph 18 to CPU. It has 2815 nodes and 88335 edges.
# (train_gat_ppi pid=106316) Loading train graph 19 to CPU. It has 3163 nodes and 97321 edges.
# (train_gat_ppi pid=106316) Loading train graph 20 to CPU. It has 3021 nodes and 94359 edges.
# (train_gat_ppi pid=106316) Loading valid graph 21 to CPU. It has 3230 nodes and 100676 edges.
# (train_gat_ppi pid=106316) Loading valid graph 22 to CPU. It has 3284 nodes and 104758 edges.
# (train_gat_ppi pid=106316) Loading test graph 23 to CPU. It has 3224 nodes and 103872 edges.
# (train_gat_ppi pid=106316) Loading test graph 24 to CPU. It has 2300 nodes and 63628 edges.
# (train_gat_ppi pid=106316) GAT training: time elapsed= 0.12 [s] | epoch=1 | batch=1 | train micro-F1=0.39492671927846673.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 1.48 [s] | epoch=1 | batch=1 | val micro-F1=0.4717266598591814
# (train_gat_ppi pid=106316) GAT training: time elapsed= 15.47 [s] | epoch=11 | batch=1 | train micro-F1=0.7375714456235999.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 16.87 [s] | epoch=11 | batch=1 | val micro-F1=0.7620488466757124
# (train_gat_ppi pid=106316) GAT training: time elapsed= 31.23 [s] | epoch=21 | batch=1 | train micro-F1=0.9038325868970711.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 32.72 [s] | epoch=21 | batch=1 | val micro-F1=0.8086320516265364
# (train_gat_ppi pid=106316) GAT training: time elapsed= 47.12 [s] | epoch=31 | batch=1 | train micro-F1=0.9355261540982264.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 48.53 [s] | epoch=31 | batch=1 | val micro-F1=0.9011865487200708
# (train_gat_ppi pid=106316) GAT training: time elapsed= 62.99 [s] | epoch=41 | batch=1 | train micro-F1=0.9430895430743651.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 64.47 [s] | epoch=41 | batch=1 | val micro-F1=0.9246381105107349
# (train_gat_ppi pid=106316) GAT training: time elapsed= 79.03 [s] | epoch=51 | batch=1 | train micro-F1=0.9637462154197884.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 80.48 [s] | epoch=51 | batch=1 | val micro-F1=0.9403648351648353
# (train_gat_ppi pid=106316) GAT training: time elapsed= 95.06 [s] | epoch=61 | batch=1 | train micro-F1=0.9887558437486346.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 96.49 [s] | epoch=61 | batch=1 | val micro-F1=0.9546312814970115
# (train_gat_ppi pid=106316) GAT training: time elapsed= 111.02 [s] | epoch=71 | batch=1 | train micro-F1=0.9897918351709165.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 112.46 [s] | epoch=71 | batch=1 | val micro-F1=0.9595844830384679
# (train_gat_ppi pid=106316) GAT training: time elapsed= 126.97 [s] | epoch=81 | batch=1 | train micro-F1=0.9920700662146833.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 128.42 [s] | epoch=81 | batch=1 | val micro-F1=0.9610352544351831
# (train_gat_ppi pid=106316) GAT training: time elapsed= 142.96 [s] | epoch=91 | batch=1 | train micro-F1=0.9831394537760625.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 144.37 [s] | epoch=91 | batch=1 | val micro-F1=0.9642427109314526
# (train_gat_ppi pid=106316) GAT training: time elapsed= 158.90 [s] | epoch=101 | batch=1 | train micro-F1=0.9935523539830996.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 160.38 [s] | epoch=101 | batch=1 | val micro-F1=0.96749816930763
# (train_gat_ppi pid=106316) GAT training: time elapsed= 175.02 [s] | epoch=111 | batch=1 | train micro-F1=0.9954302548299039.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 176.44 [s] | epoch=111 | batch=1 | val micro-F1=0.9686987795277284
# (train_gat_ppi pid=106316) GAT training: time elapsed= 190.90 [s] | epoch=121 | batch=1 | train micro-F1=0.9955018917131367.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 192.36 [s] | epoch=121 | batch=1 | val micro-F1=0.9703145023148648
# (train_gat_ppi pid=106316) GAT training: time elapsed= 206.87 [s] | epoch=131 | batch=1 | train micro-F1=0.9955734279353015.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 208.32 [s] | epoch=131 | batch=1 | val micro-F1=0.9695335390359634
# (train_gat_ppi pid=106316) GAT training: time elapsed= 222.91 [s] | epoch=141 | batch=1 | train micro-F1=0.9930958689997925.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 224.32 [s] | epoch=141 | batch=1 | val micro-F1=0.9699656361836102
# (train_gat_ppi pid=106316) GAT training: time elapsed= 238.86 [s] | epoch=151 | batch=1 | train micro-F1=0.996273259045552.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 240.29 [s] | epoch=151 | batch=1 | val micro-F1=0.9725375478381678
# (train_gat_ppi pid=106316) GAT training: time elapsed= 254.74 [s] | epoch=161 | batch=1 | train micro-F1=0.984443786265297.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 256.21 [s] | epoch=161 | batch=1 | val micro-F1=0.9683918945572849
# (train_gat_ppi pid=106316) GAT training: time elapsed= 270.73 [s] | epoch=171 | batch=1 | train micro-F1=0.9922008510548932.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 272.17 [s] | epoch=171 | batch=1 | val micro-F1=0.9729557747375119
# (train_gat_ppi pid=106316) GAT training: time elapsed= 286.62 [s] | epoch=181 | batch=1 | train micro-F1=0.9840901715253648.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 288.11 [s] | epoch=181 | batch=1 | val micro-F1=0.9705752020158137
# (train_gat_ppi pid=106316) GAT training: time elapsed= 302.62 [s] | epoch=191 | batch=1 | train micro-F1=0.8687791689333733.
# (train_gat_ppi pid=106316) GAT validation: time elapsed= 304.12 [s] | epoch=191 | batch=1 | val micro-F1=0.8616134227198738
# 2023-05-08 06:10:45,924	INFO tune.py:762 -- Total run time: 8631.49 seconds (8631.32 seconds for the tuning loop).
# (train_gat_ppi pid=106316) **************************************************
# (train_gat_ppi pid=106316) Test micro-F1 = 0.9270046420779637

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/SR-GNN/orig_paper/datasets/dataset-train-diginetica.zip", 'r')
zip_ref.extractall("/content/drive/MyDrive/DL4H_Final/datasets/")
zip_ref.close()

# %%
# %cd /content/drive/MyDrive/DL4H_Final/datasets
# Out:
# /content/drive/MyDrive/SR-GNN/orig_paper/datasets

# %%
# !python preprocess.py --dataset=diginetica
# Out:
# Namespace(dataset='diginetica')
# -- Starting @ 2023-05-06 19:10:18.918161s
# -- Reading data @ 2023-05-06 19:10:32.287916s
# Splitting date 1464134400.0
# 186670
# 15979
# [('4737', 1451606400.0), ('4741', 1451606400.0), ('4742', 1451606400.0)]
# [('289', 1464220800.0), ('290', 1464220800.0), ('302', 1464220800.0)]
# -- Splitting train set and test set @ 2023-05-06 19:10:35.327564s
# 43098
# 719470
# 60858
# [[1], [3, 4], [3]] [1451606400.0, 1451606400.0, 1451606400.0] [2, 5, 4]
# [[21553, 20071, 8762, 21566, 6381], [21553, 20071, 8762, 21566], [21553, 20071, 8762]] [1464220800.0, 1464220800.0, 1464220800.0] [21566, 6381, 21566]
# avg length:  4.850942344040704
# Done.

# %% [markdown]
# ## Reproduce the results from SR-GNN

# %%
# %cd /content/drive/MyDrive/DL4H_Final/src

# %%
## Train the base GNN model 
# !python main.py --dataset=diginetica --model=GNN
# Out:
# Namespace(dataset='diginetica', batchSize=100, hiddenSize=100, epoch=30, lr=0.001, lr_dc=0.1, lr_dc_step=3, l2=1e-05, step=1, patience=10, nonhybrid=False, validation=False, valid_portion=0.1)
# -------------------------------------------------------
# epoch:  0
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:139: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# start training:  2023-05-06 19:27:05.976381
# /content/drive/MyDrive/SR-GNN/orig_paper/pytorch_code/model.py:115: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   A = trans_to_cuda(torch.Tensor(A).float())
# [0/7195] Loss: 10.6728
# [1440/7195] Loss: 8.8680
# [2880/7195] Loss: 6.8838
# [4320/7195] Loss: 6.0367
# [5760/7195] Loss: 5.6701
# 	Loss:	50932.078
# start predicting:  2023-05-06 19:33:55.264334
# Best Result:
# 	Recall@20:	44.2423	MMR@20:	14.0486	Epoch:	0,	0
# -------------------------------------------------------
# epoch:  1
# start training:  2023-05-06 19:34:17.380135
# [0/7195] Loss: 5.1191
# [1440/7195] Loss: 5.7019
# [2880/7195] Loss: 5.2911
# [4320/7195] Loss: 5.4294
# [5760/7195] Loss: 5.0805
# 	Loss:	38185.148
# start predicting:  2023-05-06 19:41:01.911713
# Best Result:
# 	Recall@20:	47.3627	MMR@20:	15.1188	Epoch:	1,	1
# -------------------------------------------------------
# epoch:  2
# start training:  2023-05-06 19:41:23.759342
# [0/7195] Loss: 4.6873
# [1440/7195] Loss: 4.2879
# [2880/7195] Loss: 4.2731
# [4320/7195] Loss: 4.3850
# [5760/7195] Loss: 4.2536
# 	Loss:	32143.209
# start predicting:  2023-05-06 19:48:04.871742
# Best Result:
# 	Recall@20:	51.7105	MMR@20:	17.8522	Epoch:	2,	2
# -------------------------------------------------------
# epoch:  3
# start training:  2023-05-06 19:48:26.448613
# [0/7195] Loss: 4.1556
# [1440/7195] Loss: 4.2866
# [2880/7195] Loss: 4.6690
# [4320/7195] Loss: 4.4437
# [5760/7195] Loss: 4.0889
# 	Loss:	30720.848
# start predicting:  2023-05-06 19:55:05.559524
# Best Result:
# 	Recall@20:	51.7105	MMR@20:	17.9340	Epoch:	2,	3
# -------------------------------------------------------
# epoch:  4
# start training:  2023-05-06 19:55:27.140528
# [0/7195] Loss: 3.9335
# [1440/7195] Loss: 4.0603
# [2880/7195] Loss: 4.2399
# [4320/7195] Loss: 4.3571
# [5760/7195] Loss: 4.2086
# 	Loss:	29975.584
# start predicting:  2023-05-06 20:02:08.332909
# Best Result:
# 	Recall@20:	51.7105	MMR@20:	17.9340	Epoch:	2,	3
# -------------------------------------------------------
# epoch:  5
# start training:  2023-05-06 20:02:29.804231
# [0/7195] Loss: 4.0147
# [1440/7195] Loss: 4.0121
# [2880/7195] Loss: 4.0963
# [4320/7195] Loss: 3.9582
# [5760/7195] Loss: 3.7974
# 	Loss:	28567.322
# start predicting:  2023-05-06 20:09:11.436862
# Best Result:
# 	Recall@20:	51.7105	MMR@20:	17.9340	Epoch:	2,	3
# -------------------------------------------------------
# epoch:  6
# start training:  2023-05-06 20:09:33.204789
# [0/7195] Loss: 4.2173
# [1440/7195] Loss: 4.3090
# [2880/7195] Loss: 4.6425
# [4320/7195] Loss: 4.1207
# [5760/7195] Loss: 3.8053
# 	Loss:	28402.502
# start predicting:  2023-05-06 20:16:15.958923
# Best Result:
# 	Recall@20:	51.7105	MMR@20:	17.9340	Epoch:	2,	3
# -------------------------------------------------------
# epoch:  7
# start training:  2023-05-06 20:16:37.745234
# [0/7195] Loss: 3.7184
# [1440/7195] Loss: 3.7056
# [2880/7195] Loss: 4.0892
# [4320/7195] Loss: 3.8545
# [5760/7195] Loss: 3.8312
# 	Loss:	28282.816
# start predicting:  2023-05-06 20:23:20.786733
# Best Result:
# 	Recall@20:	51.7105	MMR@20:	17.9340	Epoch:	2,	3
# -------------------------------------------------------
# epoch:  8
# start training:  2023-05-06 20:23:42.632522
# [0/7195] Loss: 4.0673
# [1440/7195] Loss: 3.6719
# [2880/7195] Loss: 3.7690
# [4320/7195] Loss: 3.9497
# [5760/7195] Loss: 3.6265
# 	Loss:	28081.295
# start predicting:  2023-05-06 20:30:24.735760
# Best Result:
# 	Recall@20:	51.7105	MMR@20:	17.9340	Epoch:	2,	3
# -------------------------------------------------------
# epoch:  9
# start training:  2023-05-06 20:30:46.508361
# [0/7195] Loss: 3.6737
# [1440/7195] Loss: 3.7180
# [2880/7195] Loss: 3.9579
# [4320/7195] Loss: 3.7518
# [5760/7195] Loss: 4.1402
# 	Loss:	28069.830
# start predicting:  2023-05-06 20:37:30.687710
# Best Result:
# 	Recall@20:	51.7105	MMR@20:	17.9340	Epoch:	2,	3
# -------------------------------------------------------
# epoch:  10
# start training:  2023-05-06 20:37:52.678077
# [0/7195] Loss: 3.8008
# [1440/7195] Loss: 3.6976
# [2880/7195] Loss: 3.9805
# [4320/7195] Loss: 3.8999
# [5760/7195] Loss: 4.0428
# 	Loss:	28058.719
# start predicting:  2023-05-06 20:44:37.425224
# Best Result:
# 	Recall@20:	51.7105	MMR@20:	17.9340	Epoch:	2,	3
# -------------------------------------------------------
# epoch:  11
# start training:  2023-05-06 20:44:59.278019
# [0/7195] Loss: 3.9004
# [1440/7195] Loss: 3.3852
# [2880/7195] Loss: 3.8395
# [4320/7195] Loss: 4.1617
# [5760/7195] Loss: 4.0105
# 	Loss:	28037.631
# start predicting:  2023-05-06 20:51:43.356871
# Best Result:
# 	Recall@20:	51.7105	MMR@20:	17.9340	Epoch:	2,	3
# -------------------------------------------------------
# epoch:  12
# start training:  2023-05-06 20:52:05.195559
# [0/7195] Loss: 3.9374
# [1440/7195] Loss: 3.7639
# [2880/7195] Loss: 3.8047
# [4320/7195] Loss: 4.7589
# [5760/7195] Loss: 3.8259
# 	Loss:	28036.520
# start predicting:  2023-05-06 20:58:48.154608
# Best Result:
# 	Recall@20:	51.7105	MMR@20:	17.9340	Epoch:	2,	3
# -------------------------------------------------------
# epoch:  13
# start training:  2023-05-06 20:59:10.062510
# [0/7195] Loss: 3.8427
# [1440/7195] Loss: 3.7035
# [2880/7195] Loss: 3.8886
# [4320/7195] Loss: 3.4972
# [5760/7195] Loss: 3.7216
# 	Loss:	28035.156
# start predicting:  2023-05-06 21:05:53.230997
# Best Result:
# 	Recall@20:	51.7105	MMR@20:	17.9340	Epoch:	2,	3
# -------------------------------------------------------
# Run time: 5949.298939 s

# %% [markdown]
# ## Using Other Attention Layers

# %%
# Train the self-attention Variation
# !python main.py --dataset=diginetica --model=GCSAN
# Out:
# Namespace(dataset='diginetica', batchSize=50, hiddenSize=120, epoch=30, lr=0.001, lr_dc=0.1, lr_dc_step=3, l2=1e-05, step=1, patience=10, nonhybrid=False, validation=False, valid_portion=0.1, dynamic=False)
# -------------------------------------------------------
# epoch:  0
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:139: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# start training:  2023-05-07 22:10:46.867991
# /content/drive/MyDrive/SR-GNN/GCSAN/pytorch_code/model.py:258: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   A = trans_to_cuda(torch.Tensor(A).float())
# [0/14390] Loss: 10.6635
# [2879/14390] Loss: 8.8186
# [5758/14390] Loss: 7.7137
# [8637/14390] Loss: 7.4009
# [11516/14390] Loss: 5.9949
# 	Loss:	111584.617
# start predicting:  2023-05-07 22:19:14.509211
# Best Result:
# 	Recall@20:	34.5016	MMR@20:	10.0339	Epoch:	0,	0
# -------------------------------------------------------
# epoch:  1
# start training:  2023-05-07 22:19:41.590879
# [0/14390] Loss: 6.3254
# [2879/14390] Loss: 5.4605
# [5758/14390] Loss: 6.2063
# [8637/14390] Loss: 5.9369
# [11516/14390] Loss: 5.8932
# 	Loss:	86674.406
# start predicting:  2023-05-07 22:28:01.658884
# Best Result:
# 	Recall@20:	40.9313	MMR@20:	12.5781	Epoch:	1,	1
# -------------------------------------------------------
# epoch:  2
# start training:  2023-05-07 22:28:27.442537
# [0/14390] Loss: 5.7418
# [2879/14390] Loss: 5.3963
# [5758/14390] Loss: 5.6415
# [8637/14390] Loss: 4.8531
# [11516/14390] Loss: 4.9262
# 	Loss:	72152.023
# start predicting:  2023-05-07 22:36:43.781446
# Best Result:
# 	Recall@20:	47.9428	MMR@20:	16.1374	Epoch:	2,	2
# -------------------------------------------------------
# epoch:  3
# start training:  2023-05-07 22:37:10.483771
# [0/14390] Loss: 4.2847
# [2879/14390] Loss: 4.7593
# [5758/14390] Loss: 4.9353
# [8637/14390] Loss: 4.8168
# [11516/14390] Loss: 4.5029
# 	Loss:	68446.281
# start predicting:  2023-05-07 22:45:28.628782
# Best Result:
# 	Recall@20:	48.3026	MMR@20:	16.3255	Epoch:	3,	3
# -------------------------------------------------------
# epoch:  4
# start training:  2023-05-07 22:45:54.624085
# [0/14390] Loss: 4.4632
# [2879/14390] Loss: 4.5002
# [5758/14390] Loss: 5.2939
# [8637/14390] Loss: 4.3960
# [11516/14390] Loss: 4.2641
# 	Loss:	66865.156
# start predicting:  2023-05-07 22:54:08.702092
# Best Result:
# 	Recall@20:	48.3026	MMR@20:	16.3520	Epoch:	3,	4
# -------------------------------------------------------
# epoch:  5
# start training:  2023-05-07 22:54:35.229073
# [0/14390] Loss: 4.2975
# [2879/14390] Loss: 4.8197
# [5758/14390] Loss: 4.3237
# [8637/14390] Loss: 3.9120
# [11516/14390] Loss: 4.1032
# 	Loss:	62900.344
# start predicting:  2023-05-07 23:02:48.633660
# Best Result:
# 	Recall@20:	48.7956	MMR@20:	16.6877	Epoch:	5,	5
# -------------------------------------------------------
# epoch:  6
# start training:  2023-05-07 23:03:14.983853
# [0/14390] Loss: 4.4217
# [2879/14390] Loss: 4.3495
# [5758/14390] Loss: 4.1340
# [8637/14390] Loss: 4.4357
# [11516/14390] Loss: 3.8067
# 	Loss:	62171.055
# start predicting:  2023-05-07 23:11:26.993943
# Best Result:
# 	Recall@20:	48.7956	MMR@20:	16.6877	Epoch:	5,	5
# -------------------------------------------------------
# epoch:  7
# start training:  2023-05-07 23:11:53.598828
# [0/14390] Loss: 3.9607
# [2879/14390] Loss: 4.4714
# [5758/14390] Loss: 4.1683
# [8637/14390] Loss: 4.9713
# [11516/14390] Loss: 3.9915
# 	Loss:	61862.531
# start predicting:  2023-05-07 23:20:02.804037
# Best Result:
# 	Recall@20:	48.7956	MMR@20:	16.6877	Epoch:	5,	5
# -------------------------------------------------------
# epoch:  8
# start training:  2023-05-07 23:20:29.103091
# [0/14390] Loss: 3.9573
# [2879/14390] Loss: 5.0520
# [5758/14390] Loss: 4.0192
# [8637/14390] Loss: 4.2597
# [11516/14390] Loss: 3.6263
# 	Loss:	61122.594
# start predicting:  2023-05-07 23:28:42.243325
# Best Result:
# 	Recall@20:	48.7956	MMR@20:	16.6877	Epoch:	5,	5
# -------------------------------------------------------
# epoch:  9
# start training:  2023-05-07 23:29:08.706182
# [0/14390] Loss: 4.2549
# [2879/14390] Loss: 4.4259
# [5758/14390] Loss: 4.4278
# [8637/14390] Loss: 4.5302
# [11516/14390] Loss: 4.1416
# 	Loss:	61073.812
# start predicting:  2023-05-07 23:37:20.334256
# Best Result:
# 	Recall@20:	48.7956	MMR@20:	16.6877	Epoch:	5,	5
# -------------------------------------------------------
# epoch:  10
# start training:  2023-05-07 23:37:46.106478
# [0/14390] Loss: 3.7082
# [2879/14390] Loss: 4.0625
# [5758/14390] Loss: 4.7106
# [8637/14390] Loss: 3.4382
# [11516/14390] Loss: 4.0648
# 	Loss:	61047.617
# start predicting:  2023-05-07 23:45:58.657416
# Best Result:
# 	Recall@20:	48.7956	MMR@20:	16.6877	Epoch:	5,	5
# -------------------------------------------------------
# epoch:  11
# start training:  2023-05-07 23:46:24.413969
# [0/14390] Loss: 3.9589
# [2879/14390] Loss: 4.5764
# [5758/14390] Loss: 3.6622
# [8637/14390] Loss: 3.9498
# [11516/14390] Loss: 4.0541
# 	Loss:	60961.707
# start predicting:  2023-05-07 23:54:36.618959
# Best Result:
# 	Recall@20:	48.7956	MMR@20:	16.6877	Epoch:	5,	5
# -------------------------------------------------------
# epoch:  12
# start training:  2023-05-07 23:55:02.748570
# [0/14390] Loss: 4.1943
# [2879/14390] Loss: 3.7390
# [5758/14390] Loss: 4.4195
# [8637/14390] Loss: 4.5272
# [11516/14390] Loss: 3.9437
# 	Loss:	60958.117
# start predicting:  2023-05-08 00:03:17.686146
# Best Result:
# 	Recall@20:	48.7956	MMR@20:	16.6877	Epoch:	5,	5
# -------------------------------------------------------
# epoch:  13
# start training:  2023-05-08 00:03:43.725817
# [0/14390] Loss: 4.3470
# [2879/14390] Loss: 4.2551
# [5758/14390] Loss: 4.4005
# [8637/14390] Loss: 3.8054
# [11516/14390] Loss: 4.5791
# 	Loss:	60948.383
# start predicting:  2023-05-08 00:11:55.925871
# Best Result:
# 	Recall@20:	48.7956	MMR@20:	16.6877	Epoch:	5,	5
# -------------------------------------------------------
# epoch:  14
# start training:  2023-05-08 00:12:23.048971
# [0/14390] Loss: 3.9921
# [2879/14390] Loss: 4.5417
# [5758/14390] Loss: 4.1658
# [8637/14390] Loss: 4.3510
# [11516/14390] Loss: 4.2657
# 	Loss:	60941.160
# start predicting:  2023-05-08 00:20:37.455667
# Best Result:
# 	Recall@20:	48.7956	MMR@20:	16.6877	Epoch:	5,	5
# -------------------------------------------------------
# epoch:  15
# start training:  2023-05-08 00:21:03.353707
# [0/14390] Loss: 3.9815
# [2879/14390] Loss: 4.3953
# [5758/14390] Loss: 4.9374
# [8637/14390] Loss: 4.0198
# [11516/14390] Loss: 4.4257
# 	Loss:	60943.855
# start predicting:  2023-05-08 00:29:21.222254
# Best Result:
# 	Recall@20:	48.7956	MMR@20:	16.6877	Epoch:	5,	5
# -------------------------------------------------------
# Run time: 8340.510190 s

# %%
# GCSAN for yoochoose1_64
# !python main.py --dataset=yoochoose1_64
# Out:
# Namespace(dataset='yoochoose1_64', batchSize=50, hiddenSize=120, epoch=30, lr=0.001, lr_dc=0.1, lr_dc_step=3, l2=1e-05, step=1, patience=10, nonhybrid=False, validation=False, valid_portion=0.1, dynamic=False)
# -------------------------------------------------------
# epoch:  0
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:139: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# start training:  2023-05-08 07:08:51.777595
# /content/drive/MyDrive/SR-GNN/GCSAN/pytorch_code/model.py:258: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   A = trans_to_cuda(torch.Tensor(A).float())
# [0/7398] Loss: 10.5207
# [1480/7398] Loss: 7.2021
# [2960/7398] Loss: 6.7552
# [4440/7398] Loss: 5.9518
# [5920/7398] Loss: 6.1582
# 	Loss:	45059.945
# start predicting:  2023-05-08 07:17:02.650447
# Best Result:
# 	Recall@20:	60.5460	MMR@20:	23.3308	Epoch:	0,	0
# -------------------------------------------------------
# epoch:  1
# start training:  2023-05-08 07:17:34.470590
# [0/7398] Loss: 5.2449
# [1480/7398] Loss: 5.5261
# [2960/7398] Loss: 4.6513
# [4440/7398] Loss: 4.8553
# [5920/7398] Loss: 4.7125
# 	Loss:	35882.973
# start predicting:  2023-05-08 07:25:42.613701
# Best Result:
# 	Recall@20:	65.9898	MMR@20:	26.4745	Epoch:	1,	1
# -------------------------------------------------------
# epoch:  2
# start training:  2023-05-08 07:26:14.313796
# [0/7398] Loss: 4.6034
# [1480/7398] Loss: 4.1657
# [2960/7398] Loss: 4.0672
# [4440/7398] Loss: 4.1307
# [5920/7398] Loss: 4.2934
# 	Loss:	31438.844
# start predicting:  2023-05-08 07:34:19.884917
# Best Result:
# 	Recall@20:	69.1581	MMR@20:	29.4231	Epoch:	2,	2
# -------------------------------------------------------
# epoch:  3
# start training:  2023-05-08 07:34:51.575881
# [0/7398] Loss: 4.3310
# [1480/7398] Loss: 4.3109
# [2960/7398] Loss: 4.3864
# [4440/7398] Loss: 4.6161
# [5920/7398] Loss: 3.7408
# 	Loss:	30534.113
# start predicting:  2023-05-08 07:42:53.367309
# Best Result:
# 	Recall@20:	69.3692	MMR@20:	29.4708	Epoch:	3,	3
# -------------------------------------------------------
# epoch:  4
# start training:  2023-05-08 07:43:24.788382
# [0/7398] Loss: 3.8318
# [1480/7398] Loss: 3.7910
# [2960/7398] Loss: 3.6249
# [4440/7398] Loss: 3.8005
# [5920/7398] Loss: 4.0878
# 	Loss:	30031.732
# start predicting:  2023-05-08 07:51:27.652199
# Best Result:
# 	Recall@20:	69.5785	MMR@20:	29.5792	Epoch:	4,	4
# -------------------------------------------------------
# epoch:  5
# start training:  2023-05-08 07:51:59.010487
# [0/7398] Loss: 4.1603
# [1480/7398] Loss: 3.5486
# [2960/7398] Loss: 3.9163
# [4440/7398] Loss: 4.2846
# [5920/7398] Loss: 3.8544
# 	Loss:	29168.170
# start predicting:  2023-05-08 08:00:03.248047
# Best Result:
# 	Recall@20:	69.6662	MMR@20:	29.8313	Epoch:	5,	5
# -------------------------------------------------------
# epoch:  6
# start training:  2023-05-08 08:00:34.823316
# [0/7398] Loss: 3.4899
# [1480/7398] Loss: 3.6631
# [2960/7398] Loss: 3.9599
# [4440/7398] Loss: 3.7423
# [5920/7398] Loss: 3.7274
# 	Loss:	29043.879
# start predicting:  2023-05-08 08:08:37.689536
# Best Result:
# 	Recall@20:	69.6680	MMR@20:	29.8970	Epoch:	6,	6
# -------------------------------------------------------
# epoch:  7
# start training:  2023-05-08 08:09:09.230580
# [0/7398] Loss: 3.8393
# [1480/7398] Loss: 3.6188
# [2960/7398] Loss: 3.4534
# [4440/7398] Loss: 3.9984
# [5920/7398] Loss: 3.8593
# 	Loss:	28969.596
# start predicting:  2023-05-08 08:17:12.906914
# Best Result:
# 	Recall@20:	69.6680	MMR@20:	29.8970	Epoch:	6,	6
# -------------------------------------------------------
# epoch:  8
# start training:  2023-05-08 08:17:44.410705
# [0/7398] Loss: 3.9448
# [1480/7398] Loss: 4.5056
# [2960/7398] Loss: 3.8189
# [4440/7398] Loss: 3.9257
# [5920/7398] Loss: 3.4178
# 	Loss:	28833.969
# start predicting:  2023-05-08 08:25:48.371000
# Best Result:
# 	Recall@20:	69.6715	MMR@20:	29.8970	Epoch:	8,	6
# -------------------------------------------------------
# epoch:  9
# start training:  2023-05-08 08:26:20.731101
# [0/7398] Loss: 4.3966
# [1480/7398] Loss: 3.8348
# [2960/7398] Loss: 3.4621
# [4440/7398] Loss: 3.6940
# [5920/7398] Loss: 3.7019
# 	Loss:	28823.193
# start predicting:  2023-05-08 08:34:41.986080
# Best Result:
# 	Recall@20:	69.6715	MMR@20:	29.8970	Epoch:	9,	6
# -------------------------------------------------------
# epoch:  10
# start training:  2023-05-08 08:35:15.583864
# [0/7398] Loss: 3.8740
# [1480/7398] Loss: 3.8959
# [2960/7398] Loss: 3.9574
# [4440/7398] Loss: 4.0541
# [5920/7398] Loss: 3.8960
# 	Loss:	28811.906
# start predicting:  2023-05-08 08:43:43.446063
# Best Result:
# 	Recall@20:	69.6715	MMR@20:	29.8970	Epoch:	9,	6
# -------------------------------------------------------
# epoch:  11
# start training:  2023-05-08 08:44:16.469213
# [0/7398] Loss: 3.8112
# [1480/7398] Loss: 3.4912
# [2960/7398] Loss: 4.3176
# [4440/7398] Loss: 3.8828
# [5920/7398] Loss: 4.0390
# 	Loss:	28799.221
# start predicting:  2023-05-08 08:52:43.119353
# Best Result:
# 	Recall@20:	69.6751	MMR@20:	29.8970	Epoch:	11,	6
# -------------------------------------------------------
# epoch:  12
# start training:  2023-05-08 08:53:16.851501
# [0/7398] Loss: 4.0392
# [1480/7398] Loss: 4.7446
# [2960/7398] Loss: 4.1998
# [4440/7398] Loss: 4.1459
# [5920/7398] Loss: 4.0665
# 	Loss:	28799.213
# start predicting:  2023-05-08 09:01:42.868021
# Best Result:
# 	Recall@20:	69.6751	MMR@20:	29.8970	Epoch:	11,	6
# -------------------------------------------------------
# epoch:  13
# start training:  2023-05-08 09:02:15.818057
# [0/7398] Loss: 3.4677
# [1480/7398] Loss: 3.7783
# [2960/7398] Loss: 4.0420
# [4440/7398] Loss: 3.5294
# [5920/7398] Loss: 4.1517
# 	Loss:	28797.059
# start predicting:  2023-05-08 09:10:40.525948
# Best Result:
# 	Recall@20:	69.6751	MMR@20:	29.8970	Epoch:	11,	6
# -------------------------------------------------------
# epoch:  14
# start training:  2023-05-08 09:11:13.963269
# [0/7398] Loss: 4.1530
# [1480/7398] Loss: 3.3815
# [2960/7398] Loss: 4.0210
# [4440/7398] Loss: 3.8985
# [5920/7398] Loss: 3.7022
# 	Loss:	28797.586
# start predicting:  2023-05-08 09:19:40.918088
# Best Result:
# 	Recall@20:	69.6751	MMR@20:	29.8970	Epoch:	11,	6
# -------------------------------------------------------
# epoch:  15
# start training:  2023-05-08 09:20:13.607423
# [0/7398] Loss: 4.1737
# [1480/7398] Loss: 4.9718
# [2960/7398] Loss: 3.6047
# [4440/7398] Loss: 3.9602
# [5920/7398] Loss: 3.4496
# 	Loss:	28798.773
# start predicting:  2023-05-08 09:28:37.569305
# Best Result:
# 	Recall@20:	69.6751	MMR@20:	29.8970	Epoch:	11,	6
# -------------------------------------------------------
# epoch:  16
# start training:  2023-05-08 09:29:10.386096
# [0/7398] Loss: 4.0423
# [1480/7398] Loss: 4.3507
# [2960/7398] Loss: 3.8037
# [4440/7398] Loss: 3.4405
# [5920/7398] Loss: 3.7293
# 	Loss:	28797.701
# start predicting:  2023-05-08 09:37:34.487201
# Best Result:
# 	Recall@20:	69.6751	MMR@20:	29.8970	Epoch:	11,	6
# -------------------------------------------------------
# epoch:  17
# start training:  2023-05-08 09:38:07.696617
# [0/7398] Loss: 4.2616
# [1480/7398] Loss: 4.0180
# [2960/7398] Loss: 3.5174
# [4440/7398] Loss: 4.0771
# [5920/7398] Loss: 4.9599
# 	Loss:	28797.695
# start predicting:  2023-05-08 09:46:34.619575
# Best Result:
# 	Recall@20:	69.6751	MMR@20:	29.8970	Epoch:	11,	6
# -------------------------------------------------------
# epoch:  18
# start training:  2023-05-08 09:47:07.468051
# [0/7398] Loss: 3.8585
# [1480/7398] Loss: 4.2961
# [2960/7398] Loss: 3.9294
# [4440/7398] Loss: 3.7610
# [5920/7398] Loss: 4.1761
# 	Loss:	28795.258
# start predicting:  2023-05-08 09:55:29.521447
# Best Result:
# 	Recall@20:	69.6751	MMR@20:	29.8970	Epoch:	11,	6
# -------------------------------------------------------
# epoch:  19
# start training:  2023-05-08 09:56:02.273395
# [0/7398] Loss: 3.5369
# [1480/7398] Loss: 4.1508
# [2960/7398] Loss: 3.9782
# [4440/7398] Loss: 3.7500
# [5920/7398] Loss: 4.0888
# 	Loss:	28798.295
# start predicting:  2023-05-08 10:04:24.468446
# Best Result:
# 	Recall@20:	69.6751	MMR@20:	29.8970	Epoch:	11,	6
# -------------------------------------------------------
# Run time: 10565.416519 s

# %%
# Train SR-GAN model
# !python main.py --dataset=diginetica --model=SRGAN
# Out:
# 2023-05-08 23:26:31,394 main.py[line:37] Namespace(dataset='diginetica', batch_size=100, hidden_size=100, epoch=10, lr=0.001, lr_dc=0.1, lr_dc_step=3, l2=1e-05, top_k=20, patience=10)
# /usr/local/lib/python3.10/dist-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# 2023-05-08 23:26:31,525 main.py[line:52] logging to /content/drive/MyDrive/SR-GNN/geometric/src/../log/diginetica/Namespace(dataset='diginetica', batch_size=100, hidden_size=100, epoch=10, lr=0.001, lr_dc=0.1, lr_dc_step=3, l2=1e-05, top_k=20, patience=10)
# 2023-05-08 23:26:33,247 main.py[line:67] GNNModel(
#   (embedding): Embedding(43097, 100)
#   (gat1): GATConv(100, 100, heads=1)
#   (gat2): GATConv(100, 100, heads=1)
#   (e2s): Embedding2Score(
#     (W_1): Linear(in_features=100, out_features=100, bias=True)
#     (W_2): Linear(in_features=100, out_features=100, bias=True)
#     (q): Linear(in_features=100, out_features=1, bias=True)
#     (W_3): Linear(in_features=200, out_features=100, bias=True)
#   )
#   (loss_function): CrossEntropyLoss()
# )
#   0% 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:139: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# 	Loss:	513.313
# 2023-05-08 23:30:44,712 main.py[line:86] Best Result:
# 2023-05-08 23:30:44,713 main.py[line:87] 	Precision@20:	41.7628	MMR@20:	12.8747	Epoch:	0,	0
#  10% 1/10 [04:11<37:43, 251.47s/it]	Loss:	392.519
# 2023-05-08 23:34:12,586 main.py[line:86] Best Result:
# 2023-05-08 23:34:12,587 main.py[line:87] 	Precision@20:	45.3153	MMR@20:	14.2884	Epoch:	1,	1
#  20% 2/10 [07:39<30:06, 225.82s/it]	Loss:	335.425
# 2023-05-08 23:37:39,068 main.py[line:86] Best Result:
# 2023-05-08 23:37:39,069 main.py[line:87] 	Precision@20:	49.7897	MMR@20:	16.8858	Epoch:	2,	2
#  30% 3/10 [11:05<25:18, 216.99s/it]	Loss:	322.836
# 2023-05-08 23:41:06,984 main.py[line:86] Best Result:
# 2023-05-08 23:41:06,986 main.py[line:87] 	Precision@20:	50.2974	MMR@20:	17.0983	Epoch:	3,	3
#  40% 4/10 [14:33<21:20, 213.41s/it]	Loss:	317.723
# 2023-05-08 23:44:36,337 main.py[line:86] Best Result:
# 2023-05-08 23:44:36,338 main.py[line:87] 	Precision@20:	50.3204	MMR@20:	17.1579	Epoch:	4,	4
#  50% 5/10 [18:03<17:39, 211.95s/it]	Loss:	306.820
# 2023-05-08 23:48:07,050 main.py[line:86] Best Result:
# 2023-05-08 23:48:07,052 main.py[line:87] 	Precision@20:	50.3467	MMR@20:	17.2397	Epoch:	5,	5
#  60% 6/10 [21:33<14:06, 211.53s/it]	Loss:	305.641
# 2023-05-08 23:51:39,743 main.py[line:86] Best Result:
# 2023-05-08 23:51:39,745 main.py[line:87] 	Precision@20:	50.4042	MMR@20:	17.2565	Epoch:	6,	6
#  70% 7/10 [25:06<10:35, 211.91s/it]	Loss:	304.910
# 2023-05-08 23:55:12,567 main.py[line:86] Best Result:
# 2023-05-08 23:55:12,568 main.py[line:87] 	Precision@20:	50.4042	MMR@20:	17.2661	Epoch:	7,	7
#  80% 8/10 [28:39<07:04, 212.20s/it]	Loss:	303.327
# 2023-05-08 23:58:46,445 main.py[line:86] Best Result:
# 2023-05-08 23:58:46,447 main.py[line:87] 	Precision@20:	50.4042	MMR@20:	17.2688	Epoch:	7,	8
#  90% 9/10 [32:13<03:32, 212.72s/it]	Loss:	303.265
# 2023-05-09 00:02:19,694 main.py[line:86] Best Result:
# 2023-05-09 00:02:19,695 main.py[line:87] 	Precision@20:	50.4042	MMR@20:	17.2715	Epoch:	7,	9
# 100% 10/10 [35:46<00:00, 214.65s/it]
